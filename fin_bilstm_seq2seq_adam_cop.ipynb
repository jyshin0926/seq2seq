# %% [markdown]
# ## [tensorflow seq2seq](https://www.tensorflow.org/tutorials/text/nmt_with_attention#translate)

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np,
import os
import io
import time
import pandas as pd
import numpy as np
from tensorflow.keras.layers import LSTM,Dense,Embedding,Bidirectional,Concatenate

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
data = pd.read_excel('kor.xlsx',sheet_name='Sheet1')
src = pd.DataFrame(data['ko'])
tar = pd.DataFrame(data['en'])
df = pd.concat([src, tar],axis=1)
df
# Out:
#                                ko                                                 en
# 0      나는 매일 저녁 배트를 만나러 다락방으로 가요.       I go to the attic every evening to meet Bat.
# 1              선생님 이문장이 이해가 안 가요.        Sir, I don't understand this sentence here.
# 2        컴퓨터를 시작하면 시간이 너무 빠르게 가요.      Time flies when you start using the computer.
# 3           나는 오늘 자정에 한국으로 돌아 가요.         I'm going back to Korea today at midnight.
# 4              나는 일어나자마자 화장실에 가요.             I go to bathroom as soon as I wake up.
# ...                           ...                                                ...
# 74995    나의 고민은 학교가 멀어서 통학하기 힘들어.  My worry is commuting to school because it's t...
# 74996       난 지금 내고양이때문에 충분히 힘들어.  I am going under enough difficulties because o...
# 74997       나와 대화가 어려운 것이 많이 힘들어?  Is having difficulties in talking with me too ...
# 74998       하루에 한번 연락하는게 그렇게 힘들어?           Is it that difficult to call once a day?
# 74999   어린 아이들이 스포츠를 즐기기엔 많이 힘들죠.  It is difficult for young children to enjoy sp...
#
# [75000 rows x 2 columns]

# %% [markdown]
# ### Preprocessing

# %%
# Converts the unicode file to ascii
def unicode_to_ascii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')
def en_preprocess_sentence(w):
  w = unicode_to_ascii(w.lower().strip())
  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,¿])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)
  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)
  w = w.strip()
  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
def ko_preprocess_sentence(w):
  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,¿])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)
  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^ㄱ-ㅎㅏ|가-힣?.!,¿]+", " ", w)
  w = w.strip()
  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
def preprocess_sentence(sent):
    # 위에서 구현한 함수를 내부적으로 호출
    #sent = unicode_to_ascii(sent.lower())

    # 단어와 구두점 사이에 공백을 만듭니다.
    # Ex) "he is a boy." => "he is a boy ."
    sent = re.sub(r"([?.!,¿])", r" \1", sent)

    # (a-z, A-Z, ".", "?", "!", ",") 이들을 제외하고는 전부 공백으로 변환합니다.
    sent = re.sub(r"[^ㄱ-ㅎㅏ|가-힣a-zA-Z!.?]+", r" ", sent)
    
    sent = re.sub(r"\s+", " ", sent)

    sent = '<start> ' + sent + ' <end>'
    return sent

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [KOREAN, ENGLISH]
def create_dataset(data):
    ko, en = [],[]
    for i in range(len(data)):
        src_line = data.iloc[i][0].strip()
        tar_line = data.iloc[i][1].strip()
        
        # source 데이터 전처리
        kor = [w for w in preprocess_sentence(src_line).split()]
        ko.append(kor)
        #ko.append(kor[::-1])
        
       # print(ko)
        # target 데이터 전처리
        eng = [w for w in preprocess_sentence(tar_line).split()]
        en.append(eng)
        
    return ko,en

# %%
ko_list = []
en_list = []
for i in range(4):
        src_line = df.iloc[i][0].strip()
        tar_line = df.iloc[i][1].strip()
        
        # source 데이터 전처리
        korean = [' '.join(w for w in preprocess_sentence(src_line).split())]
        ko_list.append(korean[::-1])
        
       # print(ko)
        # target 데이터 전처리
        english = [w for w in preprocess_sentence(tar_line).split()]
        en_list.append(english)
print(ko_list)
# Out:
# [['<start> 나는 매일 저녁 배트를 만나러 다락방으로 가요 . <end>'], ['<start> 선생님 이문장이 이해가 안 가요 . <end>'], ['<start> 컴퓨터를 시작하면 시간이 너무 빠르게 가요 . <end>'], ['<start> 나는 오늘 자정에 한국으로 돌아 가요 . <end>']]

# %%
ko, en = create_dataset(df)

# %%
# Out:
# [['<start>', '나는', '매일', '저녁', '배트를', '만나러', '다락방으로', '가요', '.', '<end>'],
#  ['<start>', '선생님', '이문장이', '이해가', '안', '가요', '.', '<end>'],
#  ['<start>', '컴퓨터를', '시작하면', '시간이', '너무', '빠르게', '가요', '.', '<end>'],
#  ['<start>', '나는', '오늘', '자정에', '한국으로', '돌아', '가요', '.', '<end>'],
#  ['<start>', '나는', '일어나자마자', '화장실에', '가요', '.', '<end>'],
#  ['<start>',
#   '지금',
#   '잠을',
#   '자면',
#   '깨어나지',
#   '못할',
#   '거',
#   '같아서',
#   '지금',
#   '가요',
#   '.',
#   '<end>'],
#  ['<start>', '학교가', '끝나자마자', '기숙사로', '가요', '.', '<end>'],
#  ['<start>', '대한민국', '남자라면', '모두', '대에', '의무적으로', '군대에', '가요', '.', '<end>'],
#  ['<start>', '오늘밤에', '비자', '때문에', '한국에', '가요', '.', '<end>'],
#  ['<start>', '오늘은', '새', '자동차를', '받으러', '가요', '.', '<end>'],
#  ['<start>', '급한', '일이', '있어서', '손님', '만나러', '가요', '.', '<end>'],
#  ['<start>', '그는', '조금', '있으면', '수원으로', '가요', '.', '<end>'],
#  ['<start>', '동물병원도', '있기', '때문에', '강아지들을', '데리고도', '자주', '가요', '.', '<end>'],
#  ['<start>', '씻고', '교복을', '입고', '학교로', '가요', '.', '<end>'],
#  ['<start>', '내일', '아침', '일찍', '얼음', '낚시', '가요', '.', '<end>'],
#  ['<start>', '다른', '어떤', '일을', '하기', '위해', '서울', '가요', '.', '<end>'],
#  ['<start>', '영화', '같은', '일이', '현실이', '되어', '가요', '.', '<end>'],
#  ['<start>', '나도', '항상', '일찍', '일어나서', '학교를', '가요', '.', '<end>'],
#  ['<start>', '나는', '이제', '일', '마치고', '집에', '가요', '.', '<end>'],
#  ['<start>', '그녀는', '목요일에', '항상', '피아노', '학원에', '가요', '.', '<end>'],
#  ['<start>', '그녀는', '화요일에', '항상', '할아버지', '집에', '가요', '.', '<end>'],
#  ['<start>', '우리는', '금요일마다', '음악', '학원에', '가요', '.', '<end>'],
#  ['<start>', '우리는', '일주일에', '일', '학교에', '가요', '.', '<end>'],
#  ['<start>', '우리는', '토요일날', '부여로', '놀러', '가요', '.', '<end>'],
#  ['<start>', '우리는', '토요일에', '왔고', '금요일에', '돌아', '가요', '.', '<end>'],
#  ['<start>', '슈퍼마켓에', '일주일에', '한번', '가요', '.', '<end>'],
#  ['<start>', '은행에서', '볼일을', '끝내고', '친구를', '만나러', '가요', '.', '<end>'],
#  ['<start>', '오늘은', '월요일', '시간이', '빨리', '가요', '.', '<end>'],
#  ['<start>', '오늘은', '금요일이다', '추석도', '다', '끝나', '가요', '.', '<end>'],
#  ['<start>', '다음주', '월요일에', '사무실을', '가요', '.', '<end>'],
#  ['<start>', '다음주', '목요일', '일에', '한국으로', '돌아', '가요', '.', '<end>'],
#  ['<start>', '이번주', '토요일에', '같이', '영화보러', '가요', '.', '<end>'],
#  ['<start>', '이번주', '토요일은', '내가', '학생', '들과', '롯데', '월드를', '가요', '.', '<end>'],
#  ['<start>', '이번주', '토요일이면', '나는', '한국으로', '가요', '.', '<end>'],
#  ['<start>', '이번주', '금요일에', '레고', '랜드에', '가요', '.', '<end>'],
#  ['<start>', '다음주', '월요일에', '친구와', '영어', '마을에', '가요', '.', '<end>'],
#  ['<start>', '이번주', '일요일에', '베트남에', '가요', '.', '<end>'],
#  ['<start>', '다음주', '월요일까지만', '학교에', '가요', '.', '<end>'],
#  ['<start>', '이번주', '목요일에', '나는', '할머니', '집에', '가요', '.', '<end>'],
#  ['<start>', '이번주', '금요일부터', '이탈리아로', '가족', '여행을', '가요', '.', '<end>'],
#  ['<start>', '이번주', '금요일에', '언니가', '유학을', '가요', '.', '<end>'],
#  ['<start>', '그래서', '연예인', '들에게', '관심이', '많이', '가요', '.', '<end>'],
#  ['<start>', '당신의', '남편인', '나는', '점심', '먹으러', '가요', '.', '<end>'],
#  ['<start>', '여행책이랑', '인터넷을', '활용해서', '준비해서', '가요', '.', '<end>'],
#  ['<start>', '그중', '한', '아이의', '부모도', '같이', '가요', '.', '<end>'],
#  ['<start>', '그가', '주인공이면', '영화의', '내용을', '이끌어', '가요', '.', '<end>'],
#  ['<start>', '그리고', '시험이', '끝난', '다음날에는', '현장체험을', '가요', '.', '<end>'],
#  ['<start>', '왜', '나한테', '이러는지', '이해가', '안', '가요', '.', '<end>'],
#  ['<start>', '내일도', '시험이기', '때문에', '학교를', '안', '가요', '.', '<end>'],
#  ['<start>', '그래서', '수입이', '적은', '사람', '들은', '필리핀에', '가요', '.', '<end>'],
#  ['<start>', '크리스마스', '이브', '날', '밤에', '몰래', '선물을', '놓고', '가요', '.', '<end>'],
#  ['<start>', '내년에', '말레이시아로', '연수를', '가요', '.', '<end>'],
#  ['<start>', '저녁에', '회식이', '있어', '강남에', '가요', '.', '<end>'],
#  ['<start>', '여름에', '해변이', '아름다워서', '가요', '.', '<end>'],
#  ['<start>', '한국은', '가을이', '점점', '깊어', '가요', '.', '<end>'],
#  ['<start>', '다음', '주에', '타이완으로', '여행을', '가요', '.', '<end>'],
#  ['<start>', '나는', '곧', '편의점', '아르바이트를', '하러', '가요', '.', '<end>'],
#  ['<start>', '우리는', '마법의', '양탄자를', '타고', '미국을', '가요', '.', '<end>'],
#  ['<start>', '휴일에는', '나의', '남편과', '산에', '가요', '.', '<end>'],
#  ['<start>', '금요일은', '나의', '생일', '이에서', '피자를', '먹으러', '가요', '.', '<end>'],
#  ['<start>', '이번주에', '너의', '나라에', '여행을', '가요', '.', '<end>'],
#  ['<start>', '베트남에', '다음주말이나', '그다음주초에', '들어', '가요', '.', '<end>'],
#  ['<start>', '가끔', '뮤지컬을', '보기', '위해', '극장에', '가요', '.', '<end>'],
#  ['<start>', '나의', '가치관을', '찾으려고', '난', '산에', '가요', '.', '<end>'],
#  ['<start>', '나는', '미용실을', '갔다가', '댄스', '수업을', '가요', '.', '<end>'],
#  ['<start>', '나는', '옷', '들을', '가방에', '챙겨', '가요', '.', '<end>'],
#  ['<start>', '나는', '김', '군을', '데려다', '주고', '돌아', '가요', '.', '<end>'],
#  ['<start>', '나의', '남동생은', '일요일마다', '아침에', '공원을', '조깅하러', '가요', '.', '<end>'],
#  ['<start>', '그리고', '당신을', '만나러', '공항으로', '가요', '.', '<end>'],
#  ['<start>', '우리는', '대학을', '가기', '위해', '일반', '고등학교를', '가요', '.', '<end>'],
#  ['<start>', '학교와', '학원을', '마치고', '늦은', '밤', '집으로', '가요', '.', '<end>'],
#  ['<start>', '당신의', '사진을', '보면', '나는', '시간이', '금방', '가요', '.', '<end>'],
#  ['<start>', '토요일은', '일을', '하고', '일요일엔', '성당에', '가요', '.', '<end>'],
#  ['<start>', '난', '주러', '왔을', '뿐인데', '오히려', '내가', '받고', '가요', '.', '<end>'],
#  ['<start>', '필리핀', '사업을', '시작하기', '위해', '준비가', '다', '되어', '가요', '.', '<end>'],
#  ['<start>', '그의', '여동생은', '매일', '학교에', '버스', '타고', '가요', '.', '<end>'],
#  ['<start>', '그리고', '내일은', '롯데', '월드에', '가요', '.', '<end>'],
#  ['<start>', '무', '슬림', '들은', '금식', '기간에', '전통', '시장에', '가요', '.', '<end>'],
#  ['<start>', '하늘아', '오늘은', '아빠가', '늦게', '집에', '가요', '.', '<end>'],
#  ['<start>', '눈', '오는', '날은', '다', '들', '어린이가', '되어', '가요', '.', '<end>'],
#  ['<start>', '한국의', '음식은', '서구식으로', '변해', '가요', '.', '<end>'],
#  ['<start>', '내', '친구들은', '거의', '다음', '주에', '가요', '.', '<end>'],
#  ['<start>', '고등학생들은', '학교를', '졸업한', '후', '대학에', '들어', '가요', '.', '<end>'],
#  ['<start>', '대부분', '장난으로', '하시는', '분들이니', '웃고', '넘어', '가요', '.', '<end>'],
#  ['<start>', '내일은', '병원으로', '검사하러', '가요', '.', '<end>'],
#  ['<start>', '난', '조금', '있으면', '마치고', '집에', '가요', '.', '<end>'],
#  ['<start>', '그', '다음엔', '유산소', '운동을', '하러', '가요', '.', '<end>'],
#  ['<start>', '금전적인', '여유가', '있다면', '꼭', '프랑스에', '가요', '.', '<end>'],
#  ['<start>', '나는', '옷을', '위해', '한', '달에', '번', '쇼핑하러', '가요', '.', '<end>'],
#  ['<start>', '돈을', '벌기', '위해', '일본으로', '몸을', '팔러', '가요', '.', '<end>'],
#  ['<start>', '일을', '하기', '위해', '도시로', '많이', '가요', '.', '<end>'],
#  ['<start>', '점심에', '샌드위치를', '먹으러', '공원에', '가요', '.', '<end>'],
#  ['<start>', '우리는', '월말에', '싱가폴에', '가요', '.', '<end>'],
#  ['<start>', '나는', '장애', '원인에', '대한', '의심이', '가요', '.', '<end>'],
#  ['<start>', '나는', '지금', '울산에', '시험치러', '가요', '.', '<end>'],
#  ['<start>', '나는', '걷기', '운동을', '위해', '그곳을', '가요', '.', '<end>'],
#  ['<start>', '우리는', '새로운', '길을', '만들어', '가요', '.', '<end>'],
#  ['<start>', '덕분에', '즐거운', '추억', '많이', '가지고', '돌아', '가요', '.', '<end>'],
#  ['<start>', '그', '학교는', '우리', '학교에서', '나', '혼자', '가요', '.', '<end>'],
#  ['<start>', '연간', '많은', '외국인', '들이', '서울에', '가요', '.', '<end>'],
#  ['<start>', '어제', '밤에', '왔고', '오늘', '밤에', '가요', '.', '<end>'],
#  ['<start>', '나는', '애슐리와', '아웃백을', '자주', '가요', '.', '<end>'],
#  ['<start>', '다음주에', '나와', '함께', '그곳에', '가요', '.', '<end>'],
#  ['<start>', '나는', '종종', '올림픽', '공원으로', '산책을', '가요', '.', '<end>'],
#  ['<start>', '나는', '내일', '오전에', '합창단', '연습을', '가요', '.', '<end>'],
#  ['<start>', '사람', '들은', '예술과', '성을', '관련시키는지', '이해', '안', '가요', '.', '<end>'],
#  ['<start>', '한국', '학생', '열', '명', '중', '여덟', '명은', '대학을', '가요', '.', '<end>'],
#  ['<start>', '나는', '오늘', '여드름', '때문에', '피부과에', '가요', '.', '<end>'],
#  ['<start>', '그리고', '저녁엔', '언니네', '집에', '가요', '.', '<end>'],
#  ['<start>', '이번', '주', '중에', '베트남에', '꼭', '가요', '.', '<end>'],
#  ['<start>', '내가', '수요일에', '아들과', '함께', '뉴욕에', '가요', '.', '<end>'],
#  ['<start>', '나는', '필리핀에서', '정말', '많은', '것을', '배워', '가요', '.', '<end>'],
#  ['<start>', '나는', '월에', '스카이', '다이빙을', '하러', '가요', '.', '<end>'],
#  ['<start>', '오빠', '수영장에서', '수영하고', '점심', '먹으러', '가요', '.', '<end>'],
#  ['<start>', '나는', '바닷가에', '놀러갈', '때', '폭죽을', '챙겨', '가요', '.', '<end>'],
#  ['<start>', '질은', '일주일에', '한번', '그의', '할머니를', '만나러', '가요', '.', '<end>'],
#  ['<start>', '나는', '일요일에는', '일찍', '일어나서', '교회', '가요', '.', '<end>'],
#  ['<start>', '나는', '군산항에', '배가', '들어올', '때마다', '항상', '가요', '.', '<end>'],
#  ['<start>', '이번', '목요일에', '저희', '나라로', '돌아', '가요', '.', '<end>'],
#  ['<start>', '나는', '월에', '어학', '연수를', '가요', '.', '<end>'],
#  ['<start>', '나는', '이번주에', '예비군', '훈련하러', '가요', '.', '<end>'],
#  ['<start>', '나는', '백화점에', '장보러', '자주', '가요', '.', '<end>'],
#  ['<start>', '나는', '당구장에', '매주', '주말마다', '가요', '.', '<end>'],
#  ['<start>', '나는', '월에', '미국으로', '휴가를', '가요', '.', '<end>'],
#  ['<start>', '나는', '필리핀에는', '당신을', '만나러', '가요', '.', '<end>'],
#  ['<start>', '나는', '수영장에', '수영하러', '매일', '아침', '운전해서', '가요', '.', '<end>'],
#  ['<start>', '미국', '딸', '집에', '개월', '간', '여행을', '가요', '.', '<end>'],
#  ['<start>', '그는', '이번주에', '캄보디아에', '가요', '.', '<end>'],
#  ['<start>', '그는', '일주일에', '보통', '두', '번', '공원에', '가요', '.', '<end>'],
#  ['<start>', '그럼', '이번에', '나', '혼자', '베트남에', '가요', '.', '<end>'],
#  ['<start>', '그리고', '오후에는', '차를', '찾으러', '가요', '.', '<end>'],
#  ['<start>', '그녀는', '서울에서', '부산까지', '기차를', '타고', '가요', '.', '<end>'],
#  ['<start>', '우리는', '주말에', '아틀란타에', '가요', '.', '<end>'],
#  ['<start>', '우리는', '회사에서', '가을', '등산을', '가요', '.', '<end>'],
#  ['<start>', '우리는', '학교에', '왔다', '그리고', '영화', '구경하러', '가요', '.', '<end>'],
#  ['<start>', '교수님이', '집에', '우리를', '초대해서', '가요', '.', '<end>'],
#  ['<start>', '마닐라', '공항에서', '두', '시간', '자동차를', '타고', '가요', '.', '<end>'],
#  ['<start>', '하지만', '당신에게', '많은', '걸', '배우고', '가요', '.', '<end>'],
#  ['<start>', '내일은', '경주에', '친구', '들과', '수련회를', '가요', '.', '<end>'],
#  ['<start>',
#   '오늘은',
#   '일본에',
#   '살고',
#   '있는',
#   '언니를',
#   '만나러',
#   '일본에',
#   '가요',
#   '.',
#   '<end>'],
#  ['<start>', '당신이', '한국에', '못', '오시면', '내가', '태국으로', '가요', '.', '<end>'],
#  ['<start>', '남편이', '한국에서', '오면', '여행을', '가요', '.', '<end>'],
#  ['<start>', '금요일', '저녁에', '와서', '일요일', '저녁에', '가요', '.', '<end>'],
#  ['<start>', '일요일', '오후에는', '사무실에', '가요', '.', '<end>'],
#  ['<start>', '완전히', '충전하면', '시간', '정도', '가요', '.', '<end>'],
#  ['<start>',
#   '그리고',
#   '런던에서',
#   '유로스타를',
#   '타고',
#   '잉글랜드를',
#   '떠나',
#   '독일로',
#   '가요',
#   '.',
#   '<end>'],
#  ['<start>', '설령', '비가와도', '그래도', '우리는', '가요', '.', '<end>'],
#  ['<start>', '나는', '대한항공을', '타고', '중국을', '가요', '.', '<end>'],
#  ['<start>', '아기의', '출생신고', '등록을', '하기위해', '한국을', '가요', '.', '<end>'],
#  ['<start>', '한', '달에', '번', '정도', '쇼핑하러', '가요', '.', '<end>'],
#  ['<start>', '저는', '시합을', '보러', '자주', '야구장에', '가요', '.', '<end>'],
#  ['<start>', '역까지는', '자전거', '오토바이로', '가요', '.', '<end>'],
#  ['<start>', '설날은', '거의', '가족이랑', '친척집에', '가요', '.', '<end>'],
#  ['<start>', '동급원단에', '비해', '구김이', '덜', '가요', '.', '<end>'],
#  ['<start>', '다음에', '차', '한', '잔이라도', '하러', '가요', '.', '<end>'],
#  ['<start>', '여름', '방학에', '같이', '하와이에', '가요', '.', '<end>'],
#  ['<start>', '제', '고등학교', '졸업생', '대부분은', '대학에', '가요', '.', '<end>'],
#  ['<start>',
#   '나의',
#   '모험가',
#   '이야기는',
#   '두려움을',
#   '이겨내고',
#   '새로운세계에',
#   '가요',
#   '.',
#   '<end>'],
#  ['<start>', '아니오', '고객을', '만나러', '도쿄에', '가요', '.', '<end>'],
#  ['<start>',
#   '꼭',
#   '그렇지는',
#   '않아',
#   '나는',
#   '친구를',
#   '만나면',
#   '주로',
#   '카페를',
#   '가요',
#   '.',
#   '<end>'],
#  ['<start>',
#   '여러',
#   '친구들과',
#   '함께',
#   '그림을',
#   '그리고',
#   '전시회에',
#   '견학을',
#   '가요',
#   '.',
#   '<end>'],
#  ['<start>', '친구들과', '여행경비를', '차곡치곡모아서', '가요', '.', '<end>'],
#  ['<start>',
#   '그래서',
#   '부산에',
#   '온',
#   '사람들이',
#   '꼭',
#   '들려',
#   '사진을',
#   '찍고',
#   '가요',
#   '.',
#   '<end>'],
#  ['<start>', '이', '분은', '저희랑', '차를', '같이타고', '명동으로', '가요', '.', '<end>'],
#  ['<start>', '이', '비행기는', '바르샤바를', '거쳐', '쾰른을', '가요', '.', '<end>'],
#  ['<start>', '내일부터', '일간', '친구와', '함께', '풀만으로', '여행', '가요', '.', '<end>'],
#  ['<start>', '두', '번째', '신호를', '좌측으로', '돌아서', '가요', '.', '<end>'],
#  ['<start>',
#   '우리는',
#   '일을',
#   '마친',
#   '뒤',
#   '자주',
#   '동료와',
#   '어울려',
#   '술을',
#   '마시러',
#   '가요',
#   '.',
#   '<end>'],
#  ['<start>', '저는', '조사할', '것이', '있을', '때는', '반드시', '도서관에', '가요', '.', '<end>'],
#  ['<start>', '벌금이', '확정되면', '벌금고지서가', '당신에게', '가요', '.', '<end>'],
#  ['<start>', '제가', '대한항공을', '타고', '밴쿠버에', '가요', '.', '<end>'],
#  ['<start>', '저는', '교육', '분야나', '취업', '관련', '뉴스에', '관심이', '가요', '.', '<end>'],
#  ['<start>', '그는', '커피', '마시러', '스타벅스에', '가요', '.', '<end>'],
#  ['<start>',
#   '아빠는',
#   '꼼꼬미와',
#   '함께',
#   '우리',
#   '집에',
#   '동물원을',
#   '만들어',
#   '가요',
#   '.',
#   '<end>'],
#  ['<start>', '봉사', '활동', '후', '많은', '점을', '배워', '가요', '.', '<end>'],
#  ['<start>', '저는', '이번주', '주말에', '일본에', '가요', '.', '<end>'],
#  ['<start>',
#   '하늘은',
#   '점점',
#   '어두워질수록',
#   '손에',
#   '보이는',
#   '하늘은',
#   '점점',
#   '밝아져만',
#   '가요',
#   '.',
#   '<end>'],
#  ['<start>', '약속대로', '책상', '위에', '키와', '금액을', '두고', '가요', '.', '<end>'],
#  ['<start>', '얼마나', '당황스러웠을지', '짐작이', '가요', '.', '<end>'],
#  ['<start>', '제', '열차가', '시카고를', '거쳐', '디트로이트로', '가요', '.', '<end>'],
#  ['<start>', '전', '보통', '시', '분에', '회사를', '가요', '.', '<end>'],
#  ['<start>', '저는', '일주일에', '세', '번', '주입식', '학교에', '가요', '.', '<end>'],
#  ['<start>', '저는', '대개', '사무실에', '여덟시', '반에', '가요', '.', '<end>'],
#  ['<start>', '저는', '내달', '일에', '일본으로', '다시', '가요', '.', '<end>'],
#  ['<start>', '이', '옷은', '잘', '맞질', '않고', '판매가', '끝나', '가요', '.', '<end>'],
#  ['<start>', '이', '시계는', '하루에', '분', '이상', '더', '가요', '.', '<end>'],
#  ['<start>', '우리는', '유람선을', '타고', '강을', '내려', '가요', '.', '<end>'],
#  ['<start>', '저녁', '먹으러', '일본', '레스토랑에', '가요', '.', '<end>'],
#  ['<start>',
#   '저는',
#   '제',
#   '집',
#   '주변에',
#   '있는',
#   '공원에',
#   '자주',
#   '산보하러',
#   '가요',
#   '.',
#   '<end>'],
#  ['<start>', '차', '너무', '잘', '마시고', '좋은', '시간', '보내다', '가요', '.', '<end>'],
#  ['<start>', '아', '미안한데요', '제가', '오늘', '시카고에', '가요', '.', '<end>'],
#  ['<start>',
#   '스트레스',
#   '풀기',
#   '위해',
#   '한',
#   '달에',
#   '두',
#   '번',
#   '정도',
#   '가요',
#   '.',
#   '<end>'],
#  ['<start>', '비디오게임을', '잘', '하는', '사람들은', '최고', '수준까지', '가요', '.', '<end>'],
#  ['<start>', '밤에', '전기가', '꺼지면', '저는', '잠자러', '가요', '.', '<end>'],
#  ['<start>', '당신의', '설명으로는', '납득이', '안', '가요', '.', '<end>'],
#  ['<start>', '노력하고', '있어요', '그리고', '매일', '도서관에', '가요', '.', '<end>'],
#  ['<start>',
#   '네',
#   '저는',
#   '여름',
#   '휴가를',
#   '길게',
#   '내서',
#   '윈드',
#   '서핑하러',
#   '가요',
#   '.',
#   '<end>'],
#  ['<start>', '네', '일주일에', '한번', '정도는', '골프', '연습장에', '가요', '.', '<end>'],
#  ['<start>', '일년에', '한', '두번', '정도', '발레', '공연에', '가요', '.', '<end>'],
#  ['<start>', '그는', '일이', '끝나자마자', '늘', '집으로', '가요', '.', '<end>'],
#  ['<start>', '그녀는', '점점', '더', '인기가', '높아져', '가요', '.', '<end>'],
#  ['<start>', '자라면서', '더덕욱', '저를', '닮아', '가요', '.', '<end>'],
#  ['<start>', '시간을', '모으면', '시간은', '천천히', '가요', '.', '<end>'],
#  ['<start>', '한국에서', '신혼', '여행으로', '그곳', '많이', '가요', '?', '<end>'],
#  ['<start>', '한국의', '고등학교는', '방학에도', '학교를', '가요', '?', '<end>'],
#  ['<start>', '감사합니다', '하지만', '.', '다음주에는', '못', '가요', '?', '<end>'],
#  ['<start>', '우리', '함께', '캄보디아', '휴양지에', '여행을', '가요', '?', '<end>'],
#  ['<start>', '한국에는', '아침에', '식당에', '잘', '안', '가요', '?', '<end>'],
#  ['<start>', '나는', '오늘', '친구', '도와주러', '가요', '?', '<end>'],
#  ['<start>', '오늘', '교회', '친구', '들과', '설악산에', '가요', '?', '<end>'],
#  ['<start>', '오늘', '출입국', '관리', '사무소에', '교육', '받으러', '가요', '?', '<end>'],
#  ['<start>', '우리는', '만난지', '년이', '다', '되어', '가요', '?', '<end>'],
#  ['<start>', '이번', '휴가', '중국말고', '미얀마로', '가요', '?', '<end>'],
#  ['<start>', '사라는', '다음주', '토요일에', '파티에', '가요', '?', '<end>'],
#  ['<start>', '세계', '지창', '전철', '타려', '그러는데', '어디로', '가요', '?', '<end>'],
#  ['<start>', '그리고', '일요일', '점심에', '다시', '한국으로', '돌아', '가요', '?', '<end>'],
#  ['<start>', '그래서', '일주일에', '한', '번', '밖에', '안', '가요', '?', '<end>'],
#  ['<start>', '당신은', '일주일에', '몇', '번', '마켓', '가요', '?', '<end>'],
#  ['<start>', '이번주', '일요일', '월요일은', '여행을', '가요', '?', '<end>'],
#  ['<start>',
#   '여러분은',
#   '와인을',
#   '어떻게',
#   '먹어야',
#   '맛있는지',
#   '알고',
#   '계신',
#   '가요',
#   '?',
#   '<end>'],
#  ['<start>', '그는', '아까', '이미', '집에', '돌아', '가요', '?', '<end>'],
#  ['<start>', '워킹', '홀리데이', '비자로', '캐나다', '가요', '?', '<end>'],
#  ['<start>', '오늘', '다니엘이', '컨디션이', '안', '좋아서', '학교', '못', '가요', '?', '<end>'],
#  ['<start>', '볼펜이나', '종이', '연습장', '사러', '가요', '?', '<end>'],
#  ['<start>', '차량', '절도범을', '영어로', '무엇이라고', '하는', '가요', '?', '<end>'],
#  ['<start>', '그리고', '당신은', '다시', '영국으로', '가요', '?', '<end>'],
#  ['<start>', '대만에서', '좋은', '추억을', '가지고', '가요', '?', '<end>'],
#  ['<start>', '엄마', '집에', '요거트와', '과일이', '다', '떨어', '져', '가요', '?', '<end>'],
#  ['<start>', '집에', '돌아', '와서', '먹고', '태권도에', '가요', '?', '<end>'],
#  ['<start>', '나는', '친척집에', '왔다가', '이제', '집에', '가요', '?', '<end>'],
#  ['<start>', '내가', '베니스에', '갔을', '때', '같이', '가요', '?', '<end>'],
#  ['<start>', '왜', '그녀', '앞에만', '서면', '실수를', '하는', '걸', '가요', '?', '<end>'],
#  ['<start>', '다음에', '한국에', '오면', '스노보드', '타러', '같이', '가요', '?', '<end>'],
#  ['<start>', '여름에', '한국에', '오게', '된다면', '워터', '파크를', '가요', '?', '<end>'],
#  ['<start>', '그들은', '파티에서', '노래하고', '춤', '출건', '가요', '?', '<end>'],
#  ['<start>', '그녀는', '아직', '물건대금을', '이체', '하지', '않은', '건', '가요', '?', '<end>'],
#  ['<start>',
#   '그보다',
#   '그',
#   '총',
#   '겨누는',
#   '건',
#   '그만하는',
#   '게',
#   '어떤',
#   '가요',
#   '?',
#   '<end>'],
#  ['<start>', '아메리치노하면', '무엇이', '생각나시는', '가요', '?', '<end>'],
#  ['<start>', '펜실베니아로', '가는', '다음', '비행기는', '언제', '가요', '?', '<end>'],
#  ['<start>', '오른쪽으로', '꺼어져서', '미터', '가요', '?', '<end>'],
#  ['<start>', '여기가', '패트리지', '네', '집', '아닌', '가요', '?', '<end>'],
#  ['<start>', '얼마나', '자주', '우에노로', '기차가', '가요', '?', '<end>'],
#  ['<start>', '당신네', '나라에서는', '학력이', '중요한', '가요', '?', '<end>'],
#  ['<start>', '당신네', '나라에는', '편모가', '많은', '가요', '?', '<end>'],
#  ['<start>', '낯선', '사람에게', '말을', '거는', '것은', '무례한', '가요', '?', '<end>'],
#  ['<start>',
#   '후지',
#   '산처럼',
#   '일본을',
#   '대표한',
#   '곳으로',
#   '그를',
#   '모시고',
#   '가죠',
#   '.',
#   '<end>'],
#  ['<start>', '오늘은', '여기서', '그만하고', '환영회장으로', '가죠', '.', '<end>'],
#  ['<start>',
#   '다른',
#   '사람을',
#   '위해',
#   '선물을',
#   '사야',
#   '할',
#   '때나',
#   '쇼핑하러',
#   '가죠',
#   '.',
#   '<end>'],
#  ['<start>', '그래서', '오늘', '밤에', '술이나', '한잔', '하러', '가죠', '.', '<end>'],
#  ['<start>', '바다', '바닷가에', '가려면', '어디로', '가죠', '?', '<end>'],
#  ['<start>', '공항에서', '당신의', '집에', '어떻게', '가죠', '?', '<end>'],
#  ['<start>', '달링스퀘어로', '가려면', '어떻게', '가죠', '?', '<end>'],
#  ['<start>', '온라인', '쇼핑을', '이용하는', '이익은', '두', '가지', '.', '<end>'],
#  ['<start>', '오늘도', '퇴근할', '때', '우리', '차로', '같이', '갈까', '?', '<end>'],
#  ['<start>', '날씨가', '따뜻하니까', '우리', '봄', '소풍', '갈까', '?', '<end>'],
#  ['<start>', '대한', '항공', '타고', '토요일', '새벽에', '갈까', '?', '<end>'],
#  ['<start>', '나는', '어떤', '종류의', '옷을', '모임에', '입고', '갈까', '?', '<end>'],
#  ['<start>', '그럼', '일요일에', '일본', '음식점', '갈까', '?', '<end>'],
#  ['<start>', '그럼', '월요일과', '화요일', '어때', '몇', '시에', '갈까', '?', '<end>'],
#  ['<start>', '다음주', '금요일에는', '우리', '어디', '갈까', '?', '<end>'],
#  ['<start>', '여보', '우리', '이번', '여름에', '홍콩', '갈까', '?', '<end>'],
#  ['<start>', '일요일에', '같이', '피자', '먹으러', '갈까', '?', '<end>'],
#  ['<start>', '점심도', '먹었으니', '우리', '오사카성', '갈까', '?', '<end>'],
#  ['<start>', '당신이', '괜찮다면', '잠깐', '당신집에', '갈까', '?', '<end>'],
#  ['<start>', '만약', '네가', '피곤하면', '집으로', '갈래', '.', '<end>'],
#  ['<start>', '다음주', '주말에', '뉴질랜드로', '번지', '점프하러', '갈래', '.', '<end>'],
#  ['<start>', '그러면', '다음에', '만날', '땐', '파스타', '먹으러', '갈래', '?', '<end>'],
#  ['<start>', '하지만', '열심히', '연습하고', '나서', '수영장을', '갔어', '.', '<end>'],
#  ['<start>', '지난', '여름', '휴가를', '태국', '푸켓', '카', '오락으로', '갔어', '.', '<end>'],
#  ['<start>', '그는', '오늘', '휴가가', '끝나서', '군대로', '돌아', '갔어', '.', '<end>'],
#  ['<start>', '그', '가죽은', '후', '그의', '가족은', '여행을', '갔어', '.', '<end>'],
#  ['<start>', '그리고', '난', '후', '커피', '마시러', '갔어', '.', '<end>'],
#  ['<start>', '축구를', '한', '후에', '우리는', '비치를', '갔어', '.', '<end>'],
#  ['<start>', '결국', '계획은', '실패로', '돌아', '갔어', '.', '<end>'],
#  ['<start>', '첫', '번째로', '회사원', '친구는', '고등학교를', '실업계로', '갔어', '.', '<end>'],
#  ['<start>', '나는', '선교', '활동', '때문에', '인도네시아에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '오늘', '화천', '산천어', '축제에', '갔어', '.', '<end>'],
#  ['<start>', '나의', '아들', '화요일에', '군대를', '갔어', '.', '<end>'],
#  ['<start>', '가족', '들과', '홍콩', '중국', '여행을', '갔어', '.', '<end>'],
#  ['<start>',
#   '오늘은',
#   '나',
#   '혼자',
#   '지하철을',
#   '타고',
#   '사촌형',
#   '집에',
#   '놀러',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>',
#   '수학여행을',
#   '가거나',
#   '소풍을',
#   '갈',
#   '때',
#   '이',
#   '카메라를',
#   '가지고',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '친구', '들과', '해돋이를', '보러', '강원도에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '오늘', '해군', '부대', '영어', '수업을', '갔어', '.', '<end>'],
#  ['<start>', '언니는', '민망해', '하며', '자신의', '방으로', '돌아', '갔어', '.', '<end>'],
#  ['<start>', '부산에', '도착해서', '우리', '가족은', '바닷가에', '먼저', '갔어', '.', '<end>'],
#  ['<start>', '내가', '너랑', '함께', '갔었던', '고기', '집을', '갔어', '.', '<end>'],
#  ['<start>', '가족', '들과', '함께', '작년', '여름에', '휴가를', '제주에', '갔어', '.', '<end>'],
#  ['<start>', '두', '사람은', '함께', '옹달샘으로', '갔어', '.', '<end>'],
#  ['<start>', '나는', '어제', '할일을', '다하고', '롯데', '마트에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '그때', '할머니를', '보기', '위해', '시골에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '어제', '한강에', '바람', '쐬러', '갔어', '.', '<end>'],
#  ['<start>',
#   '나는',
#   '포기한',
#   '채로',
#   '그대로',
#   '버스를',
#   '타고',
#   '종점까지',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '그리고', '구입한', '후', '우리는', '삼촌', '집에', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '도착한', '후', '밥을', '먹고', '놀러', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '유명한', '코리아', '식당에', '갔어', '.', '<end>'],
#  ['<start>', '그', '당시에', '한국에', '갈려고', '했는데', '못', '갔어', '.', '<end>'],
#  ['<start>', '나는', '아들', '학교에', '상담이', '있어서', '갔어', '.', '<end>'],
#  ['<start>', '나는', '오늘', '학교가', '끝나고', '서귀포를', '갔어', '.', '<end>'],
#  ['<start>', '나는', '작년방학', '친구들과', '스키장으로', '여행을', '갔어', '.', '<end>'],
#  ['<start>',
#   '이번',
#   '현장',
#   '학습은',
#   '우리',
#   '반',
#   '친구',
#   '들과',
#   '함께',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '이번', '겨울방학에', '나는', '친구들과', '에버랜드에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '영어', '학원이', '끝나고', '아빠와', '집으로', '갔어', '.', '<end>'],
#  ['<start>', '그래서', '새', '학용품을', '사러', '홈', '플러스에', '갔어', '.', '<end>'],
#  ['<start>', '그녀는', '자수하기', '위해', '경찰서로', '갔어', '.', '<end>'],
#  ['<start>', '엄마를', '배웅하기', '위해서', '공항에', '갔어', '.', '<end>'],
#  ['<start>', '미션을', '수행하기', '위해서', '역으로', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '필리핀의', '기념품을', '파는', '곳으로', '갔어', '.', '<end>'],
#  ['<start>', '오늘은', '필리핀에서', '처음으로', '해변을', '갔어', '.', '<end>'],
#  ['<start>', '친구', '들과', '피자를', '먹고', '일산으로', '갔어', '.', '<end>'],
#  ['<start>', '그래서', '홈', '플러스에', '외식을', '하러', '갔어', '.', '<end>'],
#  ['<start>', '집에', '와서', '푹', '쉬고', '학원에', '갔어', '.', '<end>'],
#  ['<start>', '그녀는', '핸드폰충전기를', '우리집에', '놓고', '갔어', '.', '<end>'],
#  ['<start>', '어제', '밤', '남편이', '응급실에', '실려', '갔어', '.', '<end>'],
#  ['<start>', '나의', '같은', '팀의', '팀', '동료가', '휴가를', '갔어', '.', '<end>'],
#  ['<start>', '나는', '오케스트라', '연주회를', '보러', '갔어', '.', '<end>'],
#  ['<start>', '크리스마스', '트리를', '만들기', '위해', '마트에', '갔어', '.', '<end>'],
#  ['<start>', '이', '수업을', '통해', '내', '자신이', '긍정적으로', '변해', '갔어', '.', '<end>'],
#  ['<start>', '나는', '지난', '토요일', '일하고', '교회에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '배드민턴', '동호회', '회원', '들과', '야유회', '갔어', '.', '<end>'],
#  ['<start>', '오늘', '새벽부터', '일어나서', '시골', '할머니', '댁에', '갔어', '.', '<end>'],
#  ['<start>', '친구', '들은', '탑승', '시간', '때문에', '일찍', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '에펠탑을', '보고', '루브르', '박물관을', '갔어', '.', '<end>'],
#  ['<start>', '나는', '유로스타를', '타고', '프랑스로', '갔어', '.', '<end>'],
#  ['<start>', '그녀는', '마이크에', '서류를', '전해', '주러', '갔어', '.', '<end>'],
#  ['<start>', '아이', '들은', '쿠키를', '주기', '위해', '할머니', '집에', '갔어', '.', '<end>'],
#  ['<start>', '그는', '이틀', '코스로', '기술을', '배우러', '학교에', '갔어', '.', '<end>'],
#  ['<start>', '그들은', '멕시코', '칸쿤으로', '여행을', '갔어', '.', '<end>'],
#  ['<start>', '나는', '슈퍼마켓에', '엄마', '때문에', '갔어', '.', '<end>'],
#  ['<start>', '마지막으로', '케이크를', '만들기', '위해', '빵집으로', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '뮤지컬을', '보러', '혜화', '역으로', '갔어', '.', '<end>'],
#  ['<start>', '같은', '학과', '커플', '들과', '함께', '여행을', '갔어', '.', '<end>'],
#  ['<start>', '일어나서', '아침밥을', '먹고', '회사에', '갔어', '.', '<end>'],
#  ['<start>', '남편하고', '아침밥을', '먹고', '산에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '여자', '친구하고', '명동에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '어제', '친구', '아빠', '장례식에', '갔어', '.', '<end>'],
#  ['<start>', '나의', '아들', '친구에', '생일', '파티에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '어제', '친구와', '스시를', '먹으러', '갔어', '.', '<end>'],
#  ['<start>', '나의', '단짝', '친구와', '함께', '미술', '학원을', '갔어', '.', '<end>'],
#  ['<start>', '나는', '가장', '친한', '친구인', '예림이와', '대전을', '갔어', '.', '<end>'],
#  ['<start>',
#   '나는',
#   '남자',
#   '친구와',
#   '함께',
#   '달링하버에',
#   '있는',
#   '레스토랑에',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>',
#   '나는',
#   '오늘',
#   '친척',
#   '동생과',
#   '아는',
#   '언니랑',
#   '야외',
#   '수영장을',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '나는', '어제', '친구', '생일', '파트에', '갔어', '.', '<end>'],
#  ['<start>', '둘째', '아들', '친구', '생일', '잔치에', '갔어', '.', '<end>'],
#  ['<start>', '오늘', '나는', '친구', '들과', '게임방을', '갔어', '.', '<end>'],
#  ['<start>', '나와', '친한', '친구', '들은', '다', '기초반에', '갔어', '.', '<end>'],
#  ['<start>', '그래서', '내', '친구와', '운동을', '하러', '갔어', '.', '<end>'],
#  ['<start>', '친구', '딸의', '취업을', '축하하기', '위한', '모임에', '갔어', '.', '<end>'],
#  ['<start>', '나의', '딸은', '취업', '준비를', '위해', '서울에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '어제', '청주에', '있는', '장례식장에', '갔어', '.', '<end>'],
#  ['<start>', '많은', '가출', '청소년이', '집으로', '돌아', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '지하철을', '타고', '수원역에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '오늘', '처음으로', '보컬', '학원을', '갔어', '.', '<end>'],
#  ['<start>', '그녀는', '평소처럼', '머리를', '감지', '않고', '학교에', '갔어', '.', '<end>'],
#  ['<start>', '그는', '그의', '책을', '옮겨주고', '집에', '갔어', '.', '<end>'],
#  ['<start>', '내', '가방을', '찾으러', '도서관으로', '갔어', '.', '<end>'],
#  ['<start>', '나는', '오늘', '창원에', '있는', '바다에', '갔어', '.', '<end>'],
#  ['<start>', '밤', '늦게', '도착한', '우리는', '장례식장으로', '갔어', '.', '<end>'],
#  ['<start>', '오늘은', '승용차를', '타고', '조금', '멀리', '있는', '빵집에', '갔어', '.', '<end>'],
#  ['<start>', '오늘은', '자동차의', '브레이크가', '고장이나서', '카센터에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '많은', '짐을', '가지고', '새집으로', '갔어', '.', '<end>'],
#  ['<start>', '내', '남편의', '직업을', '알아보기', '위해', '갔어', '.', '<end>'],
#  ['<start>', '일요일에는', '직장', '동료', '장례식장에', '왔다', '갔어', '.', '<end>'],
#  ['<start>',
#   '나는',
#   '할아버지',
#   '생일을',
#   '축하해',
#   '주기',
#   '위해',
#   '음식점에',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '그는', '어제까지', '있다가', '서울에', '갔어', '.', '<end>'],
#  ['<start>', '내', '가족은', '지난주', '금요일', '한국으로', '돌아', '갔어', '.', '<end>'],
#  ['<start>', '그리고', '나머지', '영웅', '들은', '일상', '생활로', '돌아', '갔어', '.', '<end>'],
#  ['<start>', '내', '아들은', '지금', '샌디에고에', '어학', '연수', '갔어', '.', '<end>'],
#  ['<start>', '평소에는', '가지', '않던', '미용실에', '갔어', '.', '<end>'],
#  ['<start>', '친구와', '헤어지고', '나서는', '이비인후과에', '갔어', '.', '<end>'],
#  ['<start>', '당신을', '만나지', '못했다면', '나는', '돌아', '갔어', '.', '<end>'],
#  ['<start>',
#   '나는',
#   '지난',
#   '주말',
#   '브런치를',
#   '먹기',
#   '위해',
#   '카페',
#   '거리를',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '그들은', '지난주', '할머니', '집에', '갔어', '.', '<end>'],
#  ['<start>', '처음으로', '세종대', '왕상이', '있는', '곳에', '갔어', '.', '<end>'],
#  ['<start>', '오랜만에', '가족끼리', '영화관에', '갔어', '.', '<end>'],
#  ['<start>', '난', '친구', '가족과', '함께', '스키', '여행을', '갔어', '.', '<end>'],
#  ['<start>',
#   '나는',
#   '로스엔젤레스',
#   '라스베가스',
#   '샌프라시스코',
#   '그리고',
#   '텍사스에',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '우리는', '방향제를', '사기', '위해', '백화점에', '갔어', '.', '<end>'],
#  ['<start>', '어제', '나는', '전시회를', '보기', '위해', '서울을', '갔어', '.', '<end>'],
#  ['<start>', '이번', '새해', '전날에는', '가족', '들이랑', '같이', '바다에', '갔어', '.', '<end>'],
#  ['<start>', '난', '주', '전', '핼러윈', '파티에', '갔어', '.', '<end>'],
#  ['<start>', '어버이', '날', '전날', '케이크을', '사서', '집에', '갔어', '.', '<end>'],
#  ['<start>', '음악회는', '대전', '예술의', '전당으로', '갔어', '.', '<end>'],
#  ['<start>', '그리고', '정기적인', '친구들', '모임에', '갔어', '.', '<end>'],
#  ['<start>', '가족', '끼리', '저녁', '때', '외식하러', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '선착장에서', '배를', '타고', '보라카이로', '갔어', '.', '<end>'],
#  ['<start>', '나', '방금', '화장실', '갈려고', '했는데', '안', '갔어', '.', '<end>'],
#  ['<start>', '첫날에는', '늦잠을', '자고', '시장에', '장을', '보러', '갔어', '.', '<end>'],
#  ['<start>', '난', '오늘', '늦잠', '자서', '오전반', '못', '갔어', '.', '<end>'],
#  ['<start>', '어제', '두', '여자가', '친구의', '돈을', '훔쳐', '갔어', '.', '<end>'],
#  ['<start>', '나는', '나', '혼자', '운전해서', '백화점에', '갔어', '.', '<end>'],
#  ['<start>', '케이크을', '상자에', '넣고', '우리는', '집으로', '갔어', '.', '<end>'],
#  ['<start>', '나는', '집에', '있다가', '바로', '수학', '학원에', '갔어', '.', '<end>'],
#  ['<start>', '아침', '일찍', '일어나서', '부산에', '갔어', '.', '<end>'],
#  ['<start>', '그는', '혼자', '일해서', '도시락을', '가지고', '갔어', '.', '<end>'],
#  ['<start>', '그가', '다른', '일이', '생겨', '차를', '가지고', '서울에', '갔어', '.', '<end>'],
#  ['<start>', '그래서', '금요일부터', '토요일까지', '공부하러', '갔어', '.', '<end>'],
#  ['<start>', '난', '아빠가', '일하는', '회사', '사람들과', '횟집에', '갔어', '.', '<end>'],
#  ['<start>', '남편은', '목요일부터', '토요일까지', '출장을', '갔어', '.', '<end>'],
#  ['<start>', '개인적으로', '일자리를', '알아보러', '서울에', '있는', '코엑스로', '갔어', '.', '<end>'],
#  ['<start>', '지난주', '토요일', '날', '가족', '들과', '경주에', '갔어', '.', '<end>'],
#  ['<start>', '그', '택시는', '일부러', '먼', '길로', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '스페인의', '분위기가', '나는', '곳으로', '갔어', '.', '<end>'],
#  ['<start>', '나는', '사장님이', '초대한', '파티에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '리만', '이와', '함께', '차를', '타고', '학원에', '갔어', '.', '<end>'],
#  ['<start>', '그와', '같은', '이유로', '인해서', '나는', '못', '갔어', '.', '<end>'],
#  ['<start>', '나의', '사장님이', '다쳐서', '일을', '못', '갔어', '.', '<end>'],
#  ['<start>', '워킹', '홀리데이로', '왔지만', '그는', '여행을', '갔어', '.', '<end>'],
#  ['<start>', '그는', '여동생이', '출산하는', '것을', '도우러', '갔어', '.', '<end>'],
#  ['<start>', '그녀는', '시누이', '가족과', '함께', '갔어', '.', '<end>'],
#  ['<start>',
#   '우리는',
#   '더',
#   '이야기하기',
#   '위해',
#   '우리집',
#   '근처에',
#   '있는',
#   '카페로',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '오늘도', '수업이', '끝나고', '마트에', '갔어', '.', '<end>'],
#  ['<start>', '엄마랑', '동생이랑', '이모랑', '돼지', '고기를', '먹으러', '갔어', '.', '<end>'],
#  ['<start>', '그래서', '수업이', '끝나고', '바로', '도서관에', '갔어', '.', '<end>'],
#  ['<start>', '크리스마스', '이브에', '선물을', '받으러', '갔어', '.', '<end>'],
#  ['<start>', '오늘은', '어린이', '도서관에', '책을', '빌리러', '갔어', '.', '<end>'],
#  ['<start>', '그들은', '고양이를', '따라서', '피라미드로', '갔어', '.', '<end>'],
#  ['<start>', '남편의', '시험이', '있어서', '학교에', '갔어', '.', '<end>'],
#  ['<start>', '기념일을', '맞이해서', '유럽으로', '여행을', '갔어', '.', '<end>'],
#  ['<start>', '그의', '부모님의', '무덤을', '보기', '위해', '갔어', '.', '<end>'],
#  ['<start>', '그녀는', '그녀의', '코', '골절', '때문에', '병원에', '갔어', '.', '<end>'],
#  ['<start>', '그녀는', '그녀의', '남자', '친구', '군대', '입대식에', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '서로의', '꿈을', '위해', '다른', '대학에', '갔어', '.', '<end>'],
#  ['<start>', '그', '다섯', '명의', '영웅들이', '어디로', '갔어', '.', '<end>'],
#  ['<start>', '제임스는', '그의', '부모님과', '런던으로', '쇼핑을', '갔어', '.', '<end>'],
#  ['<start>', '다음으로', '가평의', '중심', '남이섬에', '갔어', '.', '<end>'],
#  ['<start>', '그들은', '그녀의', '가족과', '함께', '종종', '동물원에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '그', '믿음으로', '인문계', '고등학교를', '갔어', '.', '<end>'],
#  ['<start>', '퇴근', '후', '처음으로', '수영장에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '영화관을', '엄마', '차를', '타고', '갔어', '.', '<end>'],
#  ['<start>', '나는', '배고픔을', '못', '참고', '밥을', '먹으로', '갔어', '.', '<end>'],
#  ['<start>', '그가', '핸드폰을', '교실에', '놓고', '갔어', '.', '<end>'],
#  ['<start>', '이렇게', '계획을', '세우고', '점심을', '먹으러', '갔어', '.', '<end>'],
#  ['<start>', '다음날', '남편은', '소변을', '보기', '위해', '화장실에', '갔어', '.', '<end>'],
#  ['<start>', '어제는', '사진을', '찍으러', '시장에', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '쇼핑을', '끝내고', '롯데리아에', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '저녁을', '만들어서', '먹고', '시장에', '갔어', '.', '<end>'],
#  ['<start>', '그녀는', '양말을', '사기', '위해서', '가게에', '갔어', '.', '<end>'],
#  ['<start>', '맛있는', '음식을', '많이', '먹었다', '노래방도', '갔어', '.', '<end>'],
#  ['<start>',
#   '우리는',
#   '관광을',
#   '마쳤다',
#   '그리고',
#   '대전에',
#   '있는',
#   '숙소로',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '우리는', '저녁을', '먹고', '병원에', '다시', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '벚꽃을', '구경하러', '진주에', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '일정을', '마치고', '영덕에', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '음식을', '다', '먹고', '성당을', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '저녁을', '먹으러', '고기집을', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '점심을', '먹은', '후에', '선거하러', '갔어', '.', '<end>'],
#  ['<start>',
#   '우리는',
#   '미션을',
#   '수행하기',
#   '위해서',
#   '폴리',
#   '텍',
#   '대학교에',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>',
#   '우리는',
#   '점심을',
#   '먹기',
#   '위해',
#   '수목원',
#   '인근에',
#   '있는',
#   '카페에',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '다이어트', '약을', '사기', '위해', '가게에', '갔어', '.', '<end>'],
#  ['<start>', '그곳에서', '밤을', '새우고', '첫차를', '타고', '집으로', '갔어', '.', '<end>'],
#  ['<start>', '숙소에서', '짐을', '푼', '뒤', '저녁거리를', '사러', '갔어', '.', '<end>'],
#  ['<start>', '난', '오늘', '밥을', '먹고', '공원에', '갔어', '.', '<end>'],
#  ['<start>', '즐거운', '마음을', '가지고', '학교에', '갔어', '.', '<end>'],
#  ['<start>', '오늘은', '쇼핑을', '하러', '동대문을', '갔어', '.', '<end>'],
#  ['<start>', '그들은', '국경을', '넘어', '프랑스로', '갔어', '.', '<end>'],
#  ['<start>', '핸드폰', '주인을', '찾아', '주고', '학교에', '갔어', '.', '<end>'],
#  ['<start>', '우리', '애', '들은', '교회', '수련회', '갔어', '.', '<end>'],
#  ['<start>', '그리고', '그들은', '보물을', '찾으러', '갔어', '.', '<end>'],
#  ['<start>',
#   '하지만',
#   '오늘은',
#   '바로',
#   '집으로',
#   '가는',
#   '것이',
#   '아니라',
#   '친구집으로',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '한', '명이', '돈은', '주지', '않고', '휴가를', '갔어', '.', '<end>'],
#  ['<start>', '그래서', '오늘은', '다', '함께', '계곡에', '갔어', '.', '<end>'],
#  ['<start>', '정해진', '계획은', '없었지만', '저녁을', '먹을', '겸', '갔어', '.', '<end>'],
#  ['<start>', '내', '친구들은', '외국에서', '공부하는데', '난', '못', '갔어', '.', '<end>'],
#  ['<start>', '나는', '인터넷으로', '조사하고', '은행에', '갔어', '.', '<end>'],
#  ['<start>', '남편과', '점심으로', '칼국수를', '먹으러', '갔어', '.', '<end>'],
#  ['<start>', '꽃을', '보기', '위하여', '호수', '공원에', '갔어', '.', '<end>'],
#  ['<start>', '밥을', '먹기', '위하여', '학교', '식당에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '지난', '월요일', '고기', '뷔페를', '갔어', '.', '<end>'],
#  ['<start>',
#   '나는',
#   '지난',
#   '월요일에',
#   '한국',
#   '대학에',
#   '대한',
#   '설명회에',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '그녀는', '대학원', '친구들과', '함께', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '동물원', '옆에', '있는', '노래방에', '갔어', '.', '<end>'],
#  ['<start>',
#   '난',
#   '오늘',
#   '지원이랑',
#   '지원이네',
#   '가족이랑',
#   '지원이네',
#   '교회',
#   '수련회를',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '나는', '경주', '워터', '파크', '캘리포니아', '비치를', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '가까운', '슈퍼마켓으로', '갔어', '.', '<end>'],
#  ['<start>', '나는', '산에', '우리', '가족이랑', '이모네랑', '갔어', '.', '<end>'],
#  ['<start>', '밥을', '먹고', '우리', '가족은', '마사지를', '받으러', '갔어', '.', '<end>'],
#  ['<start>', '어제', '저녁', '우리', '가족은', '이모집에', '갔어', '.', '<end>'],
#  ['<start>', '그런', '다음', '우리는', '또', '노래방에도', '갔어', '.', '<end>'],
#  ['<start>', '예배', '후에', '우리는', '레스토랑에', '갔어', '.', '<end>'],
#  ['<start>', '그들은', '폭풍우를', '이겨', '내고', '모로코로', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '해수욕장에서', '놀다가', '리조트로', '갔어', '.', '<end>'],
#  ['<start>', '이번', '주', '금요일', '친구들과', '함께', '동굴을', '갔어', '.', '<end>'],
#  ['<start>', '토요일과', '일요일에는', '여자', '친구와', '결혼식에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '운전자와', '같이', '병원에', '갔어', '.', '<end>'],
#  ['<start>', '그리고', '친구와', '스파게티를', '먹으러', '갔어', '.', '<end>'],
#  ['<start>',
#   '그리고',
#   '엄마와',
#   '여동생과',
#   '함께',
#   '택시를',
#   '타고',
#   '산부인과에',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '그녀는', '버스와', '지하철을', '타고', '묘에', '갔어', '.', '<end>'],
#  ['<start>', '그녀는', '아빠와', '함께', '무사히', '집으로', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '학교와', '시장', '그리고', '오페라하우스를', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '버스와', '가까운', '곳에', '있는', '큰', '교회로', '갔어', '.', '<end>'],
#  ['<start>', '엄마랑', '언니와', '함께', '점을', '빼러', '갔어', '.', '<end>'],
#  ['<start>', '아침에', '엄마와', '함께', '쌀을', '씻으러', '갔어', '.', '<end>'],
#  ['<start>', '오늘은', '엄마와', '진원이랑', '영화를', '보러', '갔어', '.', '<end>'],
#  ['<start>', '오늘은', '어제와', '다른', '교실을', '갔어', '.', '<end>'],
#  ['<start>', '소년이', '아빠와', '함께', '치과에', '갔어', '.', '<end>'],
#  ['<start>',
#   '나는',
#   '비가',
#   '오는',
#   '것에도',
#   '불구하고',
#   '와이프를',
#   '데리러',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '내', '아내는', '오늘', '아울렛에', '쇼핑을', '갔어', '.', '<end>'],
#  ['<start>', '여권을', '가져오지', '않아서', '집으로', '돌아', '갔어', '.', '<end>'],
#  ['<start>', '나는', '학생', '예배를', '마치고', '집에', '바로', '갔어', '.', '<end>'],
#  ['<start>', '그는', '어제', '영천으로', '출장을', '갔어', '.', '<end>'],
#  ['<start>', '돈은', '지불하였는데', '물건을', '놓고', '갔어', '.', '<end>'],
#  ['<start>', '나는', '편도선염에', '의한', '고열로', '병원에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '수학', '여행을', '박', '일로', '갔어', '.', '<end>'],
#  ['<start>', '나도', '어제', '여기', '마사지', '샵을', '갔어', '.', '<end>'],
#  ['<start>', '돈도', '벌고', '여행도', '하고', '싶어서', '갔어', '.', '<end>'],
#  ['<start>', '나는', '어제', '여동생이랑', '카페에', '갔어', '.', '<end>'],
#  ['<start>',
#   '그의',
#   '사촌',
#   '여동생',
#   '남자',
#   '친구가',
#   '하는',
#   '레스토랑에',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '나는', '어제', '여러', '가지', '간식을', '준비해', '갔어', '.', '<end>'],
#  ['<start>',
#   '나는',
#   '뉴욕',
#   '여행',
#   '가이드북을',
#   '사서',
#   '열심히',
#   '공부해',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '나는', '작년', '여름', '담양으로', '가족여행을', '갔어', '.', '<end>'],
#  ['<start>', '그', '남자는', '여자와', '사랑에', '빠졌고', '점점', '변해', '갔어', '.', '<end>'],
#  ['<start>', '나는', '방과후에', '미용', '학원을', '갔어', '.', '<end>'],
#  ['<start>', '나는', '토요일에', '얼음', '축제에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '토요일에', '한옥', '마을을', '갔어', '.', '<end>'],
#  ['<start>', '나는', '콘서트에', '노래를', '들으러', '갔어', '.', '<end>'],
#  ['<start>', '나는', '토요일에', '스노우', '파크에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '토요일에', '딸', '발레', '콩쿨에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '토요일에', '너를', '만나러', '대전에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '지난주에', '가평으로', '단풍을', '보러', '갔어', '.', '<end>'],
#  ['<start>', '나는', '토요일에', '아들과', '함께', '언니네', '집에', '갔어', '.', '<end>'],
#  ['<start>', '지난', '토요일에', '나는', '딸의', '피아노', '연주회에', '갔어', '.', '<end>'],
#  ['<start>',
#   '나는',
#   '금요일에',
#   '천안으로',
#   '고등학교',
#   '친구',
#   '들을',
#   '만나러',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '나는', '제주도에서', '말도', '타고', '박물관도', '갔어', '.', '<end>'],
#  ['<start>', '내가', '프랑스에', '갔을', '때', '루브르에', '갔어', '.', '<end>'],
#  ['<start>', '옷이', '하나밖에', '없어서', '물에', '안', '들어', '갔어', '.', '<end>'],
#  ['<start>', '나는', '친구집에', '음식을', '들고', '갔어', '.', '<end>'],
#  ['<start>', '수업이', '끝난', '뒤', '타임', '스퀘어에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '일요일에', '갤러리아', '백화점에', '쇼핑하러', '갔어', '.', '<end>'],
#  ['<start>', '모두가', '버스에', '타고', '우리는', '학교로', '갔어', '.', '<end>'],
#  ['<start>', '그리고', '저녁에', '남산', '타워를', '갔어', '.', '<end>'],
#  ['<start>', '그리고', '오후에는', '버스를', '타고', '평화', '공원에', '갔어', '.', '<end>'],
#  ['<start>', '그러나', '학교에', '가지', '않으면', '엄마한테', '맞으니까', '갔어', '.', '<end>'],
#  ['<start>',
#   '왕자는',
#   '지구에',
#   '온지',
#   '년',
#   '만에',
#   '그의',
#   '별로',
#   '돌아',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '엄마는', '미국에', '갔고', '아빠는', '중국에', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '잠실에', '있는', '한강을', '갔어', '.', '<end>'],
#  ['<start>', '그래서', '아침에', '바다로', '일출을', '보러', '갔어', '.', '<end>'],
#  ['<start>', '그래서', '최근에', '엄마와', '목욕탕을', '갔어', '.', '<end>'],
#  ['<start>', '몇', '시간', '뒤에', '집에', '가기', '위에', '지하철에', '갔어', '.', '<end>'],
#  ['<start>', '나', '역시', '술에', '취했었기', '때문에', '일찍', '집에', '갔어', '.', '<end>'],
#  ['<start>', '오늘은', '학원에', '갔다가', '체육관에', '갔어', '.', '<end>'],
#  ['<start>', '오늘은', '교회에서', '행사가', '있어서', '저녁에', '교회에', '갔어', '.', '<end>'],
#  ['<start>', '당신은', '그곳에', '우리가', '필요해서', '갔어', '.', '<end>'],
#  ['<start>', '그들은', '좀전에', '사무실로', '돌아', '갔어', '.', '<end>'],
#  ['<start>', '오늘은', '점심에', '물고기를', '잡으러', '개울에', '갔어', '.', '<end>'],
#  ['<start>', '일요일', '오전에는', '아이', '들과', '수영장에', '갔어', '.', '<end>'],
#  ['<start>', '일요일', '오후에', '나는', '남편과', '함께', '코스트코에', '갔어', '.', '<end>'],
#  ['<start>', '그리고', '그', '부부는', '오른쪽', '길로', '갔어', '.', '<end>'],
#  ['<start>', '아리가', '나를', '버리고', '친구한테', '갔어', '.', '<end>'],
#  ['<start>', '은새와', '나는', '어부와', '농부에', '밥을', '먹으러', '갔어', '.', '<end>'],
#  ['<start>', '일단', '오늘도', '스쿨버스를', '타고', '학교에', '갔어', '.', '<end>'],
#  ['<start>', '그는', '오늘', '아침', '일찍', '필리핀에', '갔어', '.', '<end>'],
#  ['<start>', '하지만', '너무', '잠이와서', '집을', '갔어', '.', '<end>'],
#  ['<start>',
#   '나는',
#   '나도',
#   '모르는',
#   '사이에',
#   '커다란',
#   '그림자',
#   '안으로',
#   '들어',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '오늘', '친구들과', '함께', '새로', '문을', '연', '분식점을', '갔어', '.', '<end>'],
#  ['<start>',
#   '오늘',
#   '가족들과',
#   '함께',
#   '최근에',
#   '문을',
#   '연',
#   '레스토랑을',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '일본에서', '열리는', '은어축제를', '위해서', '초청받아서', '갔어', '.', '<end>'],
#  ['<start>', '지난', '주말', '나는', '가족들과', '함께', '캠핑을', '갔어', '.', '<end>'],
#  ['<start>', '나는', '내친구들과', '곡성으로', '캠핑을', '갔어', '.', '<end>'],
#  ['<start>', '오늘', '집', '근처에', '있는', '미용실에', '갔어', '.', '<end>'],
#  ['<start>', '날씨가', '더워', '밖으로', '외식을', '하러', '갔어', '.', '<end>'],
#  ['<start>', '나는', '학원이', '끝난', '후에', '도서관에', '갔어', '.', '<end>'],
#  ['<start>', '그래서', '나는', '밀정을', '보기', '위해', '건호집으로', '갔어', '.', '<end>'],
#  ['<start>', '첫번째는', '개월간의', '말레이시아로', '인턴십을', '갔어', '.', '<end>'],
#  ['<start>', '그리고', '나서', '시험기간이니', '도서관을', '갔어', '.', '<end>'],
#  ['<start>', '나는', '오늘', '독감이', '걸린', '것', '같아서', '병원에', '갔어', '.', '<end>'],
#  ['<start>', '오후수업을', '위해서', '각', '교실로', '갔어', '.', '<end>'],
#  ['<start>',
#   '귀여운',
#   '동물들을',
#   '구경하고',
#   '나서',
#   '우리는',
#   '블루마운틴으로',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '작년', '월', '김포로', '수련회를', '갔어', '.', '<end>'],
#  ['<start>', '우리는', '시카고를', '경유해서', '뉴요크에', '갔어', '.', '<end>'],
#  ['<start>', '나는', '영어', '공부를', '하기위해', '필리핀을', '갔어', '.', '<end>'],
#  ['<start>', '무엇인가에', '정신이', '홀린듯', '그의', '뒤를', '따라', '갔어', '.', '<end>'],
#  ['<start>', '나는', '학원을', '갔다가', '집으로', '갔어', '.', '<end>'],
#  ['<start>', '우리집에서', '회사까지', '가는', '길을', '돌아서', '갔어', '.', '<end>'],
#  ['<start>', '그', '다음날에', '우리는', '대한민국', '임시정부에', '갔어', '.', '<end>'],
#  ['<start>', '마지막', '날', '우리는', '와이탄', '야경을', '보러', '갔어', '.', '<end>'],
#  ['<start>', '배를', '타고', '오키나와로', '이동한', '뒤에', '드럭스토어를', '갔어', '.', '<end>'],
#  ['<start>', '나는', '봄', '방학때', '친구들과', '일본에', '갔어', '.', '<end>'],
#  ['<start>', '허겁지겁', '준비를', '마치고', '친구가', '일하는', '카페로', '갔어', '.', '<end>'],
#  ['<start>', '나는', '준비를', '빨리', '마치고', '학교로', '갔어', '.', '<end>'],
#  ['<start>', '나는', '태안의', '유명한', '해변인', '만리포', '해수욕장에', '갔어', '.', '<end>'],
#  ['<start>', '양떼목장을', '다', '둘러본', '후에는', '평창으로', '갔어', '.', '<end>'],
#  ['<start>',
#   '학교가',
#   '끝나고',
#   '나서',
#   '나는',
#   '내',
#   '친구',
#   '건호와',
#   '함께',
#   '시내로',
#   '곧장',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>',
#   '어찌어찌',
#   '술을',
#   '다',
#   '마시고',
#   '우리는',
#   '몽롱한',
#   '정신을',
#   '이끌고',
#   '집에',
#   '갔어',
#   '.',
#   '<end>'],
#  ['<start>', '택시도', '차도', '없이', '집에', '어떻게', '갔어', '?', '<end>'],
#  ['<start>', '차는', '올림픽', '대로에', '두고', '걸어서', '갔죠', '.', '<end>'],
#  ['<start>',
#   '그가',
#   '나이가',
#   '들면서',
#   '그녀는',
#   '점점',
#   '더',
#   '회의적이',
#   '되어',
#   '갔죠',
#   '.',
#   '<end>'],
#  ['<start>', '두', '시간', '전에', '넌', '일을', '하러', '갔지', '.', '<end>'],
#  ['<start>', '너무', '걱정하지', '마', '아이', '들은', '강해', '.', '<end>'],
#  ['<start>', '우리나라', '여자', '들도', '고집이', '강해', '.', '<end>'],
#  ['<start>', '당신', '같은', '사람은', '무엇이든', '안정시키려는', '의지가', '강해', '.', '<end>'],
#  ['<start>', '당신은', '영감이나', '직감이', '아주', '강해', '.', '<end>'],
#  ['<start>',
#   '요즘',
#   '내가',
#   '힘들어서',
#   '여러',
#   '가지',
#   '생각을',
#   '하는',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '애가', '요즘', '힘들어서', '그런', '것', '같아', '.', '<end>'],
#  ['<start>', '그는', '뭔가', '힘든', '일이', '있는', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '그것',
#   '들이',
#   '힘들지만',
#   '내',
#   '생각엔',
#   '나에게',
#   '중요한',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>',
#   '아마도',
#   '열심히',
#   '공부해서',
#   '수고했다고',
#   '주는',
#   '상같이',
#   '마련해',
#   '준',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '시기도', '굉장히', '적절했던', '것', '같아', '.', '<end>'],
#  ['<start>', '공부를', '열심히', '안해서', '그런', '것', '같아', '.', '<end>'],
#  ['<start>', '오늘은', '유난히', '피곤한', '날인', '것', '같아', '.', '<end>'],
#  ['<start>', '하느님이', '너희', '들을', '만나게', '해주신', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '이',
#   '영화가',
#   '흥행하는데는',
#   '그만한',
#   '이유가',
#   '있는',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '업무', '파악', '후', '관여', '할', '수', '있을', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '자원',
#   '봉사',
#   '후에',
#   '파티를',
#   '하면',
#   '그들이',
#   '좋아할',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '정말', '좋은', '회사에', '입사한', '거', '같아', '.', '<end>'],
#  ['<start>', '기술변경위원회의', '기능은', '다음과', '같아', '.', '<end>'],
#  ['<start>', '그래서', '전시회에서', '미팅을', '해야', '할', '것', '같아', '.', '<end>'],
#  ['<start>', '그에', '따른', '활동', '목표는', '아래와', '같아', '.', '<end>'],
#  ['<start>', '내', '가슴에', '화살이', '날아오는', '것', '같아', '.', '<end>'],
#  ['<start>', '장비는', '안정화', '되', '가고', '있는', '것', '같아', '.', '<end>'],
#  ['<start>', '이번주에', '영화를', '많이', '보는', '것', '같아', '.', '<end>'],
#  ['<start>', '난', '정말', '고혹적인', '여자인', '거', '같아', '.', '<end>'],
#  ['<start>', '내', '생각에', '호텔', '예약을', '두', '번한', '것', '같아', '.', '<end>'],
#  ['<start>', '내', '생각엔', '호텔도', '안', '좋았을', '것', '같아', '.', '<end>'],
#  ['<start>', '즐거운', '경험이', '더', '많은', '거', '같아', '.', '<end>'],
#  ['<start>',
#   '너는',
#   '보다',
#   '헌신적인',
#   '아내의',
#   '보살핌을',
#   '받는게',
#   '행복할거',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '현재까지', '진행', '경과는', '다음과', '같아', '.', '<end>'],
#  ['<start>',
#   '대부분의',
#   '현행',
#   '업무는',
#   '그대로',
#   '진행되어야',
#   '할',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '일전에도', '말했지만', '너는', '천재인', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '그는',
#   '널',
#   '위해서',
#   '돈',
#   '구하러',
#   '다니고',
#   '있는',
#   '거',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>',
#   '두',
#   '가지가',
#   '해결되면',
#   '많은',
#   '양을',
#   '팔',
#   '수',
#   '있을',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '의사가', '처방해', '주는', '약', '인', '거', '같아', '.', '<end>'],
#  ['<start>', '그녀가', '성장해', '가는', '과정인', '거', '같아', '.', '<end>'],
#  ['<start>', '스터디를', '통해', '만나게', '될', '것', '같아', '.', '<end>'],
#  ['<start>', '앞으로', '미안해', '할', '짓을', '하면', '안될', '거', '같아', '.', '<end>'],
#  ['<start>',
#   '클래식은',
#   '이해하기는',
#   '어렵지만',
#   '듣는',
#   '것은',
#   '좋은',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '종이에', '인쇄해서', '스탑모션으로', '촬영해도', '재미있을', '것', '같아', '.', '<end>'],
#  ['<start>', '넌', '운동을', '해야', '몸무게가', '증가', '할', '것', '같아', '.', '<end>'],
#  ['<start>', '이것은', '확인해서', '나에게', '알려주면', '좋을', '것', '같아', '.', '<end>'],
#  ['<start>', '당신을', '계속해서', '보면은', '사랑', '할', '것', '같아', '.', '<end>'],
#  ['<start>', '노력이', '부족해서', '합격하지', '못한', '거', '같아', '.', '<end>'],
#  ['<start>', '가족이', '건강해야', '행복한', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '당신이',
#   '얘기해',
#   '준',
#   '것과',
#   '같이',
#   '봄에',
#   '청소하는',
#   '게',
#   '좋을',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '프로페셔널', '해', '보이는', '게', '좋을', '거', '같아', '.', '<end>'],
#  ['<start>',
#   '곰곰히',
#   '생각해',
#   '보니',
#   '우리는',
#   '부부가',
#   '되기',
#   '힘',
#   '들',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '달에는', '불편함이', '많이', '있을', '것', '같아', '.', '<end>'],
#  ['<start>', '기존의', '심플함은', '유지하되', '차별화해야', '할', '것', '같아', '.', '<end>'],
#  ['<start>', '풍선의', '중요함을', '알게', '해', '준', '것', '같아', '.', '<end>'],
#  ['<start>', '아이', '들도', '할아버지를', '많이', '좋아하는', '거', '같아', '.', '<end>'],
#  ['<start>', '엄마가', '사용할', '수', '없게', '막아', '논', '것', '같아', '.', '<end>'],
#  ['<start>', '그녀는', '운동할', '때의', '모습이', '가장', '아름다운', '것', '같아', '.', '<end>'],
#  ['<start>', '앞으로', '수업할', '때', '전화기를', '바꿔야', '될', '거', '같아', '.', '<end>'],
#  ['<start>', '테마를', '선택할', '때', '관점은', '다음과', '같아', '.', '<end>'],
#  ['<start>', '그래서', '여행할', '때', '가져가면', '좋을', '것', '같아', '.', '<end>'],
#  ['<start>', '더', '알아야', '할', '것이', '많을', '거', '같아', '.', '<end>'],
#  ['<start>', '나', '화나게', '할려고', '하는', '거', '같아', '.', '<end>'],
#  ['<start>', '나는', '너가', '한국에', '없으면', '많이', '그리울', '것', '같아', '.', '<end>'],
#  ['<start>', '네', '명중', '한', '명이', '선택될', '것', '같아', '.', '<end>'],
#  ['<start>', '너는', '정말', '한국', '사람', '입맛', '같아', '.', '<end>'],
#  ['<start>', '너희들이', '한국에', '와서', '즐겁게', '보낸', '것', '같아', '.', '<end>'],
#  ['<start>', '나는', '와인', '한', '병', '마시면', '술에', '취할', '것', '같아', '.', '<end>'],
#  ['<start>', '나는', '중요한', '일을', '결정해야만', '할', '것', '같아', '.', '<end>'],
#  ['<start>', '우리가', '함께한', '시간이', '짧은', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '나에게',
#   '소중한',
#   '추억이',
#   '있기에',
#   '아직까지',
#   '잘',
#   '지내는',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '그러나', '비슷한', '제품들이', '이미', '너무', '많은', '것', '같아', '.', '<end>'],
#  ['<start>', '나', '나중에', '한국에서', '일하고', '살', '거', '같아', '.', '<end>'],
#  ['<start>', '인도는', '독특한', '문화가', '많은', '것', '같아', '.', '<end>'],
#  ['<start>', '우리는', '비슷한', '부분이', '많은', '것', '같아', '.', '<end>'],
#  ['<start>', '아무래도', '심한', '몸살이', '걸린', '거', '같아', '.', '<end>'],
#  ['<start>', '도구를', '발명한', '과학자는', '대단한', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '아무리',
#   '강인한',
#   '군인이라고',
#   '해도',
#   '슬픔은',
#   '어쩔',
#   '수',
#   '없는',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '자국민에', '대한', '배려가', '없는', '거', '같아', '.', '<end>'],
#  ['<start>', '내', '생각엔', '한국어가', '더', '쉬운', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '내',
#   '생각엔',
#   '한국에서',
#   '최고의',
#   '애니메이션',
#   '필름을',
#   '제작하는',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '그래서', '이러한', '결과가', '생긴', '것', '같아', '.', '<end>'],
#  ['<start>', '호텔에', '확인한', '요금은', '아래와', '같아', '.', '<end>'],
#  ['<start>', '이', '오돌도돌한', '감촉', '도저히', '잊지', '못할', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '그들은',
#   '요청한',
#   '일정을',
#   '기준으로',
#   '납기를',
#   '조정하려고',
#   '하는',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '대학을', '입학한', '후에', '가수가', '되어도', '좋을', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '내용을',
#   '요약한다면',
#   '더',
#   '멋진',
#   '피',
#   '피티가',
#   '될',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '당신의', '따뜻한', '손이', '느껴지는', '것', '같아', '.', '<end>'],
#  ['<start>', '당신이', '결혼하면', '그가', '돈을', '안', '줄', '것', '같아', '.', '<end>'],
#  ['<start>', '내', '이름은', '한국', '유명', '탤런트', '이름과', '같아', '.', '<end>'],
#  ['<start>', '바우처에', '대한', '세부', '사항은', '아래와', '같아', '.', '<end>'],
# ...
#  ['<start>', '진짜', '우리', '집이', '제일', '편한', '것', '같아', '.', '<end>'],
#  ['<start>', '그래서', '더', '집중을', '하고', '보았던거', '같아', '.', '<end>'],
#  ['<start>',
#   '고양이를',
#   '만질',
#   '때',
#   '털이',
#   '없으면',
#   '느낌이',
#   '이상할',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '컬러가', '더', '진했다면', '좋았을', '것', '같아', '.', '<end>'],
#  ['<start>', '그런데', '이사진에', '대한', '설명이', '빠진', '것', '같아', '.', '<end>'],
#  ['<start>', '앤드류는', '멋진', '남자가', '돼', '있을', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '내',
#   '생각엔',
#   '진돗개가',
#   '개',
#   '들',
#   '중에',
#   '가장',
#   '멋진',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '다음주부터', '진짜', '운동', '좀', '해야', '할', '것', '같아', '.', '<end>'],
#  ['<start>', '니가', '옮긴', '직장이', '얼마나', '좋은지를', '알', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '가장',
#   '좋은',
#   '직업은',
#   '내가',
#   '하고',
#   '싶은',
#   '것인',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>',
#   '그를',
#   '보면',
#   '직원',
#   '들',
#   '모두가',
#   '그를',
#   '좋아하는',
#   '거',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '굳이', '필요하지', '않다면', '서두르지', '않아도', '될', '거', '같아', '.', '<end>'],
#  ['<start>', '이번', '시험까지만', '하고', '일을', '할', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '나도',
#   '아직까지는',
#   '물부족에',
#   '대한',
#   '인식이',
#   '부족한',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>',
#   '서른',
#   '살이',
#   '지난',
#   '후로는',
#   '시간이',
#   '점점',
#   '빨리',
#   '지나가는',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>',
#   '다음',
#   '투여까지',
#   '기다리다가는',
#   '백혈구',
#   '수치가',
#   '너무',
#   '올라갈',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '물론', '무섭겠지만', '그는', '모험심이', '강한', '것', '같아', '.', '<end>'],
#  ['<start>', '더운', '여름이지만', '재미있게', '보낸', '방학인', '것', '같아', '.', '<end>'],
#  ['<start>', '그는', '배려하지', '않고', '편안하지', '않는', '것', '같아', '.', '<end>'],
#  ['<start>', '대학교', '이미지는', '나쁜', '편은', '아닌', '것', '같아', '.', '<end>'],
#  ['<start>', '바로는', '아니지만', '곧', '좋은', '결과가', '있을', '것', '같아', '.', '<end>'],
#  ['<start>', '여자도', '나쁘지만', '남자가', '더', '나쁜', '것', '같아', '.', '<end>'],
#  ['<start>', '어디로', '가는지는', '잘', '모르겠지만', '재미있을', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '하지만',
#   '나머지',
#   '수량은',
#   '다음주에',
#   '선적',
#   '해야',
#   '할',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '내', '생각에', '지오는', '귀여워서', '인기가', '많은', '것', '같아', '.', '<end>'],
#  ['<start>', '따라서', '시너지', '협상에서의', '대안은', '다음과', '같아', '.', '<end>'],
#  ['<start>', '그래서', '강아지가', '더', '친근하고', '좋은', '거', '같아', '.', '<end>'],
#  ['<start>', '한국은', '강아지나', '고양이만', '좋아하는', '거', '같아', '.', '<end>'],
#  ['<start>', '오늘은', '아쉽지만', '여기서', '끝내야', '할', '거', '같아', '.', '<end>'],
#  ['<start>', '기분은', '느끼지', '못하지만', '실력이', '좋은', '것', '같아', '.', '<end>'],
#  ['<start>', '상황이', '나빠지지는', '않을', '거', '같아', '.', '<end>'],
#  ['<start>', '시간이', '길어지는', '이유는', '아래와', '같아', '.', '<end>'],
#  ['<start>',
#   '당신이',
#   '바쁠지라도',
#   '어떤',
#   '거라도',
#   '먹는',
#   '게',
#   '좋을',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '이번주는', '잊지', '못할', '한', '주가', '될', '것', '같아', '.', '<end>'],
#  ['<start>', '이', '이유로', '즐거운', '경험을', '가지게', '된', '것', '같아', '.', '<end>'],
#  ['<start>', '넌', '서프라이즈', '받을', '자격이', '없는', '것', '같아', '.', '<end>'],
#  ['<start>', '나는', '생일', '중에', '월이', '가장', '좋은', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '나는',
#   '하루',
#   '중',
#   '대부분의',
#   '시간은',
#   '의자에',
#   '앉아서',
#   '보내고',
#   '있는',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>',
#   '내가',
#   '가장',
#   '중요하게',
#   '생각하는',
#   '구성',
#   '요소는',
#   '연습인',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>',
#   '내',
#   '생각엔',
#   '중국',
#   '팀으로',
#   '인해',
#   '업무가',
#   '늘어난',
#   '거',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '조용하고', '신중한', '사람이', '어울리는', '것', '같아', '.', '<end>'],
#  ['<start>', '갑자기', '스케줄이', '생겨서', '오늘은', '못', '만날', '것', '같아', '.', '<end>'],
#  ['<start>', '니가', '수업', '준비를', '안하는', '것', '같아', '.', '<end>'],
#  ['<start>', '나는', '취직', '준비로', '더', '힘', '들', '거', '같아', '.', '<end>'],
#  ['<start>', '아마', '메일', '주소가', '잘못', '된', '것', '같아', '.', '<end>'],
#  ['<start>', '나의', '카드', '주소가', '확인되지', '않아서', '인', '것', '같아', '.', '<end>'],
#  ['<start>', '나는', '왠지', '주변에', '친구가', '없는', '것', '같아', '.', '<end>'],
#  ['<start>', '내가', '저번', '주에', '했었던', '실험은', '다음과', '같아', '.', '<end>'],
#  ['<start>', '너가', '도와', '주면', '빨리', '끝날', '것', '같아', '.', '<end>'],
#  ['<start>', '교수님께서', '주제를', '정해', '주시면', '좋을', '것', '같아', '.', '<end>'],
#  ['<start>', '이마도', '이번주엔', '수업할', '수', '없을', '것', '같아', '.', '<end>'],
#  ['<start>', '정도만', '알려주시면', '우린', '좀', '더', '수월할', '것', '같아', '.', '<end>'],
#  ['<start>', '어쩌면', '주', '일정도', '있을', '것', '같아', '.', '<end>'],
#  ['<start>', '빠르면', '이번주', '안에', '갈', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '요리사가',
#   '해주는',
#   '맛있는',
#   '음식을',
#   '먹으면',
#   '좋을',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '내', '생각에', '주권으로', '사용할', '것', '같아', '.', '<end>'],
#  ['<start>', '내', '생각엔', '주소', '잘못', '적은', '거', '같아', '.', '<end>'],
#  ['<start>',
#   '이',
#   '영화의',
#   '주제는',
#   '계산',
#   '없이',
#   '사랑하라',
#   '인',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '나는', '평생', '죄책감을', '느끼며', '살', '거', '같아', '.', '<end>'],
#  ['<start>', '남자', '친구', '좋은', '사람', '만난', '것', '같아', '.', '<end>'],
#  ['<start>', '나쁜', '점과', '좋은', '점은', '있는', '것', '같아', '.', '<end>'],
#  ['<start>', '돈을', '주면', '좋겠지만', '그건', '아닌', '거', '같아', '.', '<end>'],
#  ['<start>',
#   '나',
#   '너에게',
#   '좋은',
#   '여자가',
#   '되어',
#   '주지',
#   '못하는',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '넌', '매너가', '좋아서', '인기가', '많을', '것', '같아', '.', '<end>'],
#  ['<start>', '사랑보다는', '좋아한다가', '맞는', '거', '같아', '.', '<end>'],
#  ['<start>', '오늘부터는', '좋은', '일만', '생길', '것', '같아', '.', '<end>'],
#  ['<start>', '그래서', '더', '좋은', '선수라고', '불리는', '것', '같아', '.', '<end>'],
#  ['<start>', '호주에서의', '좋은', '친구가', '될', '것', '같아', '.', '<end>'],
#  ['<start>', '나', '여기가', '좋아서', '자주', '올', '것', '같아', '.', '<end>'],
#  ['<start>', '한글은', '참', '좋은', '언어인', '것', '같아', '.', '<end>'],
#  ['<start>', '내', '인생에', '좋은', '경험이', '된', '것', '같아', '.', '<end>'],
#  ['<start>', '나는', '구기', '종목을', '거의', '좋아하는', '것', '같아', '.', '<end>'],
#  ['<start>', '걸어가다가', '종이를', '잃어', '버린', '것', '같아', '.', '<end>'],
#  ['<start>', '리더에게', '순종하는', '것이', '하느님께', '순종하는', '것과', '같아', '.', '<end>'],
#  ['<start>', '아', '이제', '좀', '감기가', '나아진', '거', '같아', '.', '<end>'],
#  ['<start>', '아마도', '한민족을', '죽인다는것', '때문인거', '같아', '.', '<end>'],
#  ['<start>', '압출기의', '구조는', '다음', '그림과', '같아', '.', '<end>'],
#  ['<start>', '외롭다고', '무조건', '그러는', '건', '아닌', '것', '같아', '.', '<end>'],
#  ['<start>', '내', '생각엔', '조금만', '갈아도', '될', '거', '같아', '.', '<end>'],
#  ['<start>',
#   '많이',
#   '좋아',
#   '졌는데',
#   '같이',
#   '가기는',
#   '힘',
#   '들',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '우리', '떨어', '져서', '시간을', '가져야', '할', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '내',
#   '돈이',
#   '빠져',
#   '나간',
#   '거라면',
#   '나는',
#   '너무',
#   '불쾌할',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>',
#   '나는',
#   '기존',
#   '제품을',
#   '사용하여',
#   '재조정을',
#   '할',
#   '수',
#   '있을',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '그가', '어제', '제대로', '말을', '못한', '것', '같아', '.', '<end>'],
#  ['<start>', '랩으로', '싼', '제품이', '고정이', '안', '된', '것', '같아', '.', '<end>'],
#  ['<start>', '어제부터', '숙제를', '미뤄', '되게', '피곤한', '하루인', '것', '같아', '.', '<end>'],
#  ['<start>', '내', '생각엔', '제자가', '시각', '장애인이', '아닌', '것', '같아', '.', '<end>'],
#  ['<start>', '그래서', '수면제가', '필요했던', '것', '같아', '.', '<end>'],
#  ['<start>', '첫', '스텝이', '제일', '중요한', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '고객은',
#   '그',
#   '제품을',
#   '사용할',
#   '의지를',
#   '여전히',
#   '가지고',
#   '있는',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '개인적으로', '제어가', '더', '재미있는', '것', '같아', '.', '<end>'],
#  ['<start>', '감사했다고', '제대로', '말하지', '않으면', '후회할', '것', '같아', '.', '<end>'],
#  ['<start>', '근데', '시간', '정말', '빨리', '가는', '것', '같아', '.', '<end>'],
#  ['<start>', '그', '가게에', '정말', '오랜만에', '간', '것', '같아', '.', '<end>'],
#  ['<start>', '잉여금을', '조정하지', '않고는', '방법이', '없는', '거', '같아', '.', '<end>'],
#  ['<start>', '눈', '사람을', '정말', '정성스럽게', '만든', '것', '같아', '.', '<end>'],
#  ['<start>', '평소에도', '걱정이', '많은', '성격의', '영향이', '큰', '것', '같아', '.', '<end>'],
#  ['<start>', '넌', '여행을', '정말', '좋아하는', '거', '같아', '.', '<end>'],
#  ['<start>', '그들은', '성', '정체성이', '다른', '것', '같아', '.', '<end>'],
#  ['<start>', '디자이너는', '정말', '멋진', '직업인', '것', '같아', '.', '<end>'],
#  ['<start>', '해리포터는', '정말', '용맹하고', '똑똑한', '것', '같아', '.', '<end>'],
#  ['<start>', '체선', '는', '점점', '더', '예뻐지는', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '사람',
#   '들이',
#   '점점',
#   '공유를',
#   '하면서',
#   '파일',
#   '다운로드가',
#   '생긴',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>',
#   '나는',
#   '계절',
#   '스포츠',
#   '중에',
#   '겨울',
#   '스포츠가',
#   '제일',
#   '재미',
#   '있는',
#   '거',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '아마', '그가', '절', '페이스', '북', '차단한', '것', '같아', '.', '<end>'],
#  ['<start>', '아이들에', '예절은', '부모닝의', '거울인거', '같아', '.', '<end>'],
#  ['<start>',
#   '나는',
#   '아까',
#   '전애',
#   '순수한',
#   '너에게',
#   '실수를',
#   '한',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '군대', '가기', '전이', '술을', '많이', '마시는', '것', '같아', '.', '<end>'],
#  ['<start>', '그가', '내', '충전기를', '가져간', '것', '같아', '.', '<end>'],
#  ['<start>', '내가', '묻기', '전에', '말해', '줬으면', '좋았을', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '집에서는',
#   '얌전하고',
#   '부모님',
#   '말씀을',
#   '잘',
#   '듣는',
#   '착한',
#   '어린이일',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '토끼는', '활동적이여서', '나랑', '잘', '맞을', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '내',
#   '생각엔',
#   '적극적이고',
#   '밝고',
#   '귀여운',
#   '여자가',
#   '너랑',
#   '어울릴',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '성격은', '개방적이지만', '약간', '내성적인', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '만약',
#   '내가',
#   '저',
#   '상황이라면',
#   '난',
#   '그러지',
#   '못할',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '내', '생각에', '쟤네', '사귀는', '거', '같아', '.', '<end>'],
#  ['<start>', '네', '나를', '재미없다고', '생각할', '것', '같아', '.', '<end>'],
#  ['<start>', '내가', '쓴', '문장에', '무엇인가', '오해가', '있는', '거', '같아', '.', '<end>'],
#  ['<start>',
#   '당분간은',
#   '시장의',
#   '움직임을',
#   '지켜보는',
#   '것이',
#   '좋을',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '올해', '중에', '가장', '많이', '웃은', '거', '같아', '.', '<end>'],
#  ['<start>', '내가', '오늘', '잘해서', '복을', '받은', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '늦게',
#   '자면',
#   '잘수록',
#   '당신이',
#   '보고',
#   '싶어',
#   '미칠',
#   '거',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '그가', '너랑', '잘', '지냈던', '게', '도움이', '된', '것', '같아', '.', '<end>'],
#  ['<start>', '너', '기타를', '잘', '치면', '매력적일', '것', '같아', '.', '<end>'],
#  ['<start>', '넌', '내', '말을', '잘못', '알아', '들은', '것', '같아', '.', '<end>'],
#  ['<start>', '띄어쓰기만', '잘하면', '더', '좋을', '것', '같아', '.', '<end>'],
#  ['<start>', '내', '인생은', '잘못', '끼워', '진', '단추와', '같아', '.', '<end>'],
#  ['<start>', '나는', '문서', '작성을', '잘할', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '우리의',
#   '수집작품',
#   '중에',
#   '추천할',
#   '만한',
#   '작품도',
#   '있을',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '이제', '나', '혼자', '여행', '잘', '할', '것', '같아', '.', '<end>'],
#  ['<start>', '우리', '둘만', '자주', '연락', '하는', '것', '같아', '.', '<end>'],
#  ['<start>', '영어', '캠프', '자료', '준비하면', '될', '것', '같아', '.', '<end>'],
#  ['<start>', '판도라의', '상자를', '열어', '버린', '것', '같아', '.', '<end>'],
#  ['<start>', '너야말로', '여자', '친구가', '많은', '것', '같아', '.', '<end>'],
#  ['<start>', '여동생의', '남자', '친구는', '매우', '좋은', '사람', '같아', '.', '<end>'],
#  ['<start>',
#   '그래서',
#   '시청자',
#   '들이',
#   '한국',
#   '드라마를',
#   '좋아하는',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '귀여워서', '남자', '들한테', '인기', '많을', '거', '같아', '.', '<end>'],
#  ['<start>', '인생은', '나', '자신과', '싸움인', '것', '같아', '.', '<end>'],
#  ['<start>', '넌', '정말', '여자', '마음을', '잘', '아는', '거', '같아', '.', '<end>'],
#  ['<start>', '화장품은', '여자의', '가장', '소중한', '물건인', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '나는',
#   '혼자',
#   '있을',
#   '때',
#   '대부분',
#   '인터넷을',
#   '하는',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '결국', '남아', '있는', '사람이', '더', '힘든', '것', '같아', '.', '<end>'],
#  ['<start>', '가장', '오래', '있는', '가족은', '아마', '부모님인', '것', '같아', '.', '<end>'],
#  ['<start>', '내가', '입고', '있는', '모든', '것이', '같아', '.', '<end>'],
#  ['<start>', '그와', '함께', '있으며', '웃음이', '날', '것', '같아', '.', '<end>'],
#  ['<start>', '그는', '흥미', '있어', '하지', '않는', '것', '같아', '.', '<end>'],
#  ['<start>', '요즘', '황사', '있어', '산책하기에', '안', '좋은', '것', '같아', '.', '<end>'],
#  ['<start>', '눈을', '감고', '있으면', '그녀가', '보일', '것', '같아', '.', '<end>'],
#  ['<start>', '앞으로', '의미있는', '일이', '더', '많이', '생길', '것', '같아', '.', '<end>'],
#  ['<start>', '공부를', '하고', '있긴', '한데', '조금', '부족한', '것', '같아', '.', '<end>'],
#  ['<start>', '하지만', '재미있는', '추억이', '된', '거', '같아', '.', '<end>'],
#  ['<start>', '니', '주변에', '있는', '여자들은', '예쁠', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '다양하고',
#   '맛있는',
#   '음식',
#   '덕분에',
#   '후회하지',
#   '않을',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '절대', '네', '생일은', '잊지', '못할', '것', '같아', '.', '<end>'],
#  ['<start>', '너의', '일은', '일정이', '빽빽한', '것', '같아', '.', '<end>'],
#  ['<start>', '하고', '있는', '일도', '잘', '될', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '내가',
#   '지금',
#   '일하는',
#   '중이라서',
#   '확인',
#   '하는',
#   '게',
#   '늦을',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '오늘', '따라', '일이', '더', '많은', '거', '같아', '.', '<end>'],
#  ['<start>', '오늘', '늦게', '일어나서', '모스만에', '가지', '못할', '거', '같아', '.', '<end>'],
#  ['<start>', '하고', '싶은', '일을', '하면', '행복할', '것', '같아', '.', '<end>'],
#  ['<start>', '그', '금액을', '일치시켜야', '할', '것', '같아', '.', '<end>'],
#  ['<start>', '그런데', '토요일에', '너는', '항상', '바쁜', '것', '같아', '.', '<end>'],
#  ['<start>', '아마도', '수요일쯤', '보낼', '수', '있을', '거', '같아', '.', '<end>'],
#  ['<start>', '아마도', '일주일', '정도', '지나면', '문제가', '없을', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '아마도',
#   '토요일',
#   '밤이나',
#   '일요일',
#   '아침에',
#   '돌아오게',
#   '될',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '난', '모르는', '일이야', '기온', '때문인', '것', '같아', '.', '<end>'],
#  ['<start>', '내', '생각에', '일할', '때', '에너지가', '넘칠', '것', '같아', '.', '<end>'],
#  ['<start>', '그래서', '월요일에', '해야', '할', '거', '같아', '.', '<end>'],
#  ['<start>', '그', '식당은', '일종의', '공연장과', '같아', '.', '<end>'],
#  ['<start>', '빨라야', '토요일에', '보낼', '수', '있을', '것', '같아', '.', '<end>'],
#  ['<start>', '당신의', '이메일은', '잘', '못', '전해진', '것', '같아', '.', '<end>'],
#  ['<start>', '토요일', '일요일은', '더', '피곤한', '거', '같아', '.', '<end>'],
#  ['<start>', '이번주', '목요일이나', '금요일', '서울에', '갈', '것', '같아', '.', '<end>'],
#  ['<start>', '이번주', '금요일', '날에', '못', '만날', '거', '같아', '.', '<end>'],
#  ['<start>', '이번주까지', '일을', '하고', '그만둬야', '될', '것', '같아', '.', '<end>'],
#  ['<start>', '이번주', '토요일에', '파티가', '못할', '거', '같아', '.', '<end>'],
#  ['<start>', '미안한데', '내일', '못', '만', '날거', '같아', '.', '<end>'],
#  ['<start>', '미안한데', '내일', '사정이', '생겨', '만나지', '못할', '것', '같아', '.', '<end>'],
#  ['<start>', '그의', '무릎', '인대가', '다친', '것', '같아', '.', '<end>'],
#  ['<start>', '나는', '약간', '인터넷', '중독인', '것', '같아', '.', '<end>'],
#  ['<start>', '누가', '너의', '인', '스타', '그램', '도용하는', '것', '같아', '.', '<end>'],
#  ['<start>', '음악은', '내', '인생의', '오아시스와', '같아', '.', '<end>'],
#  ['<start>', '그녀의', '곰', '인형은', '공포', '영화에', '나오는', '것', '같아', '.', '<end>'],
#  ['<start>', '이것이', '미국인', '들을', '힘들게', '하는', '것', '같아', '.', '<end>'],
#  ['<start>', '이름처럼', '연인', '들이', '오면', '좋을', '것', '같아', '.', '<end>'],
#  ['<start>', '당신', '응급실이라도', '가야', '하는', '거', '같아', '.', '<end>'],
#  ['<start>', '너는', '긍정적이고', '밝은', '사람', '같아', '.', '<end>'],
#  ['<start>', '오늘', '졸업식이', '있어서', '수업에', '빠져야', '할', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '내가',
#   '아픈',
#   '이유는',
#   '너무',
#   '미국',
#   '음식을',
#   '섭취해',
#   '서인',
#   '거',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '업무', '스타일이', '나와', '맞지', '않는', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '니가',
#   '좋은',
#   '이유가',
#   '단지',
#   '날',
#   '사랑해',
#   '주기',
#   '때문인',
#   '거',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '집에', '가면', '이', '영화를', '또', '찾을', '것', '같아', '.', '<end>'],
#  ['<start>', '역시', '꿈을', '이루는', '데에는', '경험이', '중요한', '것', '같아', '.', '<end>'],
#  ['<start>', '앤디', '지하철이', '조금', '늦게', '도착할', '것', '같아', '.', '<end>'],
#  ['<start>', '나는', '다음달이나', '시간이', '될', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '그런',
#   '점이',
#   '이',
#   '책을',
#   '더',
#   '재밌게',
#   '만들어',
#   '주는',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '너무', '다혈질이라', '참을성이', '부족한', '것', '같아', '.', '<end>'],
#  ['<start>', '그와', '나', '사이에는', '마무리', '될', '것', '같아', '.', '<end>'],
#  ['<start>', '어쩔', '수', '없이', '널', '계속', '봐야', '될', '것', '같아', '.', '<end>'],
#  ['<start>',
#   '내가',
#   '주인공이',
#   '되어서',
#   '사건을',
#   '해결해',
#   '나가는',
#   '것',
#   '같아',
#   '.',
#   '<end>'],
#  ['<start>', '너가', '내', '것이라면', '너무나', '행복할', '것', '같아', '.', '<end>'],
#  ['<start>', '우리가', '학생이라서', '통하는', '게', '많은', '것', '같아', '.', '<end>'],
#  ['<start>', '나에게', '권한이', '없어서', '안', '열리는', '것', '같아', '.', '<end>'],
#  ['<start>', '그리고', '성격이', '나와', '비슷한', '것', '같아', '.', '<end>'],
#  ['<start>', '그리고', '할말이', '있다면', '문자로', '하는게', '좋을것', '같아', '.', '<end>'],
#  ...]

# %%
print(ko[-2])
print(en[-2])
# Out:
# ['<start>', '하루에', '한번', '연락하는게', '그렇게', '힘들어', '?', '<end>']
# ['<start>', 'Is', 'it', 'that', 'difficult', 'to', 'call', 'once', 'a', 'day', '?', '<end>']

# %%
def tokenize(lang):
    lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
    lang_tokenizer.fit_on_texts(lang)

    tensor = lang_tokenizer.texts_to_sequences(lang)

    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,padding='post')

    return tensor, lang_tokenizer

# %%
def load_dataset(df):
  # creating cleaned input, output pairs
    inp_lang, targ_lang = create_dataset(df)
    inp_lang, targ_lang = inp_lang[:63000],targ_lang[:63000]
   # print(inp_lang, targ_lang)
    input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
    target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

    return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
# Try experimenting with the size of that dataset
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(df)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=13000)

print(input_tensor_train.shape, target_tensor_train.shape, input_tensor_val.shape, target_tensor_val.shape)
# Out:
# (50000, 17) (50000, 20) (13000, 17) (13000, 20)

# %% [markdown]
# ## tf.data 데이터 셋 생성

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 17]), TensorShape([64, 20]))

# %% [markdown]
# ## 인코더 및 디코더 모델 작성

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.bilstm = tf.keras.layers.Bidirectional(LSTM(self.enc_units,
                                       return_sequences=True,
                                       return_state=True,recurrent_initializer='glorot_uniform'))                                       
                    
    def call(self, x, hidden):
        x = self.embedding(x)
        output, state_fh, state_fc, state_bh, state_bc = self.bilstm(x, initial_state = hidden)

        return output, state_fh, state_fc, state_bh, state_bc

    def initialize_hidden_state(self):
        return [tf.zeros((self.batch_sz, self.enc_units)) for i in range(4)]

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
encoder_hidden = encoder.initialize_hidden_state()
#encoder_output, encoder_fh, encoder_sh, encoder_fc, encoder_sc = encoder(example_input_batch, encoder_hidden)
encoder_output, encoder_fh, encoder_fc, encoder_sh, encoder_sc = encoder(example_input_batch, encoder_hidden)

#encoder_states = [encoder_output, encoder_hidden]
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(encoder_output.shape))
print ('Encoder First Hidden state shape: (batch size, units) {}'.format(encoder_fh.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 17, 2048)
# Encoder First Hidden state shape: (batch size, units) (64, 1024)

# %%
encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        multiple                  19236352
# _________________________________________________________________
# bidirectional (Bidirectional multiple                  10493952
# =================================================================
# Total params: 29,730,304
# Trainable params: 29,730,304
# Non-trainable params: 0
# _________________________________________________________________

# %%
class BahdanauAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, query1, query2, values):
        # query hidden state shape == (batch_size, hidden size)
        # query_with_time_axis shape == (batch_size, 1, hidden size)
        # values shape == (batch_size, max_len, hidden size)
        # we are doing this to broadcast addition along the time axis to calculate the score
        query = Concatenate()([query1, query2])
        query_with_time_axis = tf.expand_dims(query, 1)

        # score shape == (batch_size, max_length, 1)
        # we get 1 at the last axis because we are applying score to self.V
        # the shape of the tensor before applying self.V is (batch_size, max_length, units)
        score = self.V(tf.nn.tanh(
            self.W1(query_with_time_axis) + self.W2(values)))

        # attention_weights shape == (batch_size, max_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)

        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(encoder_fh, encoder_sh, encoder_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (64, 2048)
# Attention weights shape: (batch_size, sequence_length, 1) (64, 17, 1)

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.bilstm = tf.keras.layers.Bidirectional(LSTM(self.dec_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform'))
        self.fc = tf.keras.layers.Dense(vocab_size)

        # used for attention
        self.attention = BahdanauAttention(self.dec_units)

    def call(self, x, fhidden, shidden, fcell, scell, enc_output):
        # enc_output shape == (batch_size, max_length, hidden_size)
        context_vector, attention_weights = self.attention(fhidden, shidden, enc_output)

        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)
        # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        # passing the concatenated vector to the GRU
        output, state_fh, state_fc, state_sh, state_sc = self.bilstm(x)

        # output shape == (batch_size * 1, hidden_size)
        output = tf.reshape(output, (-1, output.shape[2]))

        # output shape == (batch_size, vocab)
        x = self.fc(output)

        return x, state_fh, state_fc, state_sh, state_sc, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_output, _, _,_,_, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      encoder_fh, encoder_fc, encoder_sh, encoder_sc, encoder_output)

print ('Decoder output shape: (batch_size, vocab size) {}'.format(decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (64, 17900)

# %%
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      multiple                  4582400
# _________________________________________________________________
# bidirectional_1 (Bidirection multiple                  27271168
# _________________________________________________________________
# dense_3 (Dense)              multiple                  36677100
# _________________________________________________________________
# bahdanau_attention_1 (Bahdan multiple                  4197377
# =================================================================
# Total params: 72,728,045
# Trainable params: 72,728,045
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 옵티마이저 및 손실 함수 정의

# %%
optimizer = tf.keras.optimizers.Adam()
#optimizer = tf.keras.optimizers.SGD(learning_rate=0.75)
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
# 검사 점(오브젝트 기반 저장)
checkpoint_dir = ''
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %% [markdown]
# ## 훈련

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0

    with tf.GradientTape() as tape:
        enc_output, enc_hidden_fh, enc_hidden_fc, enc_hidden_sh,enc_hidden_sc  = encoder(inp, enc_hidden)

        dec_hidden_fh = enc_hidden_fh
        dec_hidden_sh = enc_hidden_sh
        dec_hidden_fc = enc_hidden_fc
        dec_hidden_sc = enc_hidden_sc

        dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

        # Teacher forcing - feeding the target as the next input
        for t in range(1, targ.shape[1]):
          # passing enc_output to the decoder
            predictions, dec_hidden_fh,dec_hidden_fc,dec_hidden_sh,dec_hidden_sc, _ = decoder(dec_input, dec_hidden_fh,dec_hidden_fc,dec_hidden_sh,dec_hidden_sc, enc_output)

            loss += loss_function(targ[:, t], predictions)

          # using teacher forcing
            dec_input = tf.expand_dims(targ[:, t], 1)

    batch_loss = (loss / int(targ.shape[1]))
    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %%
# from tqdm import tqdm
# EPOCHS = 10

# for epoch in tqdm(range(EPOCHS)):
#     start = time.time()

#     enc_hidden = encoder.initialize_hidden_state()
#     total_loss = 0

#     for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
#         batch_loss = train_step(inp, targ, enc_hidden)
#         total_loss += batch_loss

#         if batch % 100 == 0:
#             print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
#                                                        batch,
#                                                        batch_loss.numpy()))
#   # saving (checkpoint) the model every 2 epochs
#     if (epoch + 1) % 2 == 0:
#         checkpoint.save(file_prefix = checkpoint_prefix)

#     print('Epoch {} Loss {:.4f}'.format(epoch + 1,
#                                       total_loss / steps_per_epoch))
#     print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))

# %%
# 어순 그대로 인풋
from tqdm import tqdm
EPOCHS = 10

for epoch in tqdm(range(EPOCHS)):
    start = time.time()

    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0

    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
        batch_loss = train_step(inp, targ, enc_hidden)
        total_loss += batch_loss

        if batch % 100 == 0:
            print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                       batch,
                                                       batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
    if (epoch + 1) % 2 == 0:
        checkpoint.save(file_prefix = checkpoint_prefix)

    print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1 Batch 0 Loss 5.4854
# Epoch 1 Batch 100 Loss 2.9678
# Epoch 1 Batch 200 Loss 2.8566
# Epoch 1 Batch 300 Loss 2.5731
# Epoch 1 Batch 400 Loss 2.5340
# Epoch 1 Batch 500 Loss 2.6844
# Epoch 1 Batch 600 Loss 2.5779
# Epoch 1 Batch 700 Loss 2.3863
#  10%|█         | 1/10 [07:59<1:11:56, 479.62s/it]
# Epoch 1 Loss 2.7308
# Time taken for 1 epoch 479.6230034828186 sec
#
# Epoch 2 Batch 0 Loss 2.3692
# Epoch 2 Batch 100 Loss 2.3279
# Epoch 2 Batch 200 Loss 2.3559
# Epoch 2 Batch 300 Loss 2.1077
# Epoch 2 Batch 400 Loss 2.1161
# Epoch 2 Batch 500 Loss 2.1966
# Epoch 2 Batch 600 Loss 2.1946
# Epoch 2 Batch 700 Loss 2.0510
#  20%|██        | 2/10 [15:29<1:02:44, 470.61s/it]
# Epoch 2 Loss 2.2190
# Time taken for 1 epoch 449.56320428848267 sec
#
# Epoch 3 Batch 0 Loss 1.8867
# Epoch 3 Batch 100 Loss 1.9936
# Epoch 3 Batch 200 Loss 1.8563
# Epoch 3 Batch 300 Loss 1.8759
# Epoch 3 Batch 400 Loss 1.7496
# Epoch 3 Batch 500 Loss 1.9770
# Epoch 3 Batch 600 Loss 1.7992
# Epoch 3 Batch 700 Loss 1.8999
#  30%|███       | 3/10 [22:52<53:57, 462.50s/it]
# Epoch 3 Loss 1.8851
# Time taken for 1 epoch 443.5927984714508 sec
#
# Epoch 4 Batch 0 Loss 1.4814
# Epoch 4 Batch 100 Loss 1.5304
# Epoch 4 Batch 200 Loss 1.4774
# Epoch 4 Batch 300 Loss 1.5622
# Epoch 4 Batch 400 Loss 1.5367
# Epoch 4 Batch 500 Loss 1.6473
# Epoch 4 Batch 600 Loss 1.6583
# Epoch 4 Batch 700 Loss 1.5908
#  40%|████      | 4/10 [30:21<45:49, 458.26s/it]
# Epoch 4 Loss 1.5638
# Time taken for 1 epoch 448.36810421943665 sec
#
# Epoch 5 Batch 0 Loss 1.1633
# Epoch 5 Batch 100 Loss 1.1733
# Epoch 5 Batch 200 Loss 1.2346
# Epoch 5 Batch 300 Loss 1.2184
# Epoch 5 Batch 400 Loss 1.2984
# Epoch 5 Batch 500 Loss 1.2461
# Epoch 5 Batch 600 Loss 1.2017
# Epoch 5 Batch 700 Loss 1.3356
#  50%|█████     | 5/10 [37:45<37:50, 454.04s/it]
# Epoch 5 Loss 1.2490
# Time taken for 1 epoch 444.2026319503784 sec
#
# Epoch 6 Batch 0 Loss 0.9085
# Epoch 6 Batch 100 Loss 0.7908
# Epoch 6 Batch 200 Loss 0.9994
# Epoch 6 Batch 300 Loss 0.8872
# Epoch 6 Batch 400 Loss 1.0270
# Epoch 6 Batch 500 Loss 1.0258
# Epoch 6 Batch 600 Loss 0.9542
# Epoch 6 Batch 700 Loss 1.0843
#  60%|██████    | 6/10 [45:14<30:10, 452.55s/it]
# Epoch 6 Loss 0.9514
# Time taken for 1 epoch 449.0749008655548 sec
#
# Epoch 7 Batch 0 Loss 0.6270
# Epoch 7 Batch 100 Loss 0.6673
# Epoch 7 Batch 200 Loss 0.6881
# Epoch 7 Batch 300 Loss 0.6132
# Epoch 7 Batch 400 Loss 0.6735
# Epoch 7 Batch 500 Loss 0.7055
# Epoch 7 Batch 600 Loss 0.8371
# Epoch 7 Batch 700 Loss 0.8033
#  70%|███████   | 7/10 [52:39<22:30, 450.22s/it]
# Epoch 7 Loss 0.6943
# Time taken for 1 epoch 444.75692653656006 sec
#
# Epoch 8 Batch 0 Loss 0.4703
# Epoch 8 Batch 100 Loss 0.3999
# Epoch 8 Batch 200 Loss 0.4785
# Epoch 8 Batch 300 Loss 0.5116
# Epoch 8 Batch 400 Loss 0.5034
# Epoch 8 Batch 500 Loss 0.5276
# Epoch 8 Batch 600 Loss 0.5209
# Epoch 8 Batch 700 Loss 0.5781
#  80%|████████  | 8/10 [1:00:10<15:01, 450.57s/it]
# Epoch 8 Loss 0.4873
# Time taken for 1 epoch 451.3807373046875 sec
#
# Epoch 9 Batch 0 Loss 0.3111
# Epoch 9 Batch 100 Loss 0.2900
# Epoch 9 Batch 200 Loss 0.2793
# Epoch 9 Batch 300 Loss 0.3188
# Epoch 9 Batch 400 Loss 0.3658
# Epoch 9 Batch 500 Loss 0.3019
# Epoch 9 Batch 600 Loss 0.3819
# Epoch 9 Batch 700 Loss 0.3533
#  90%|█████████ | 9/10 [1:07:37<07:29, 449.53s/it]
# Epoch 9 Loss 0.3286
# Time taken for 1 epoch 447.09796261787415 sec
#
# Epoch 10 Batch 0 Loss 0.1776
# Epoch 10 Batch 100 Loss 0.2016
# Epoch 10 Batch 200 Loss 0.2116
# Epoch 10 Batch 300 Loss 0.1789
# Epoch 10 Batch 400 Loss 0.2317
# Epoch 10 Batch 500 Loss 0.2169
# Epoch 10 Batch 600 Loss 0.2180
# Epoch 10 Batch 700 Loss 0.2234
# 100%|██████████| 10/10 [1:15:09<00:00, 450.97s/it]
# Epoch 10 Loss 0.2128
# Time taken for 1 epoch 451.9692220687866 sec

# %%
def evaluate(sentence):
    attention_plot = np.zeros((max_length_targ, max_length_inp))

    sentence = preprocess_sentence(sentence)

    inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
    inputs = tf.convert_to_tensor(inputs)

    result = ''

    hidden = [tf.zeros((1, units)) for i in range(4)]
    enc_out, enc_hidden_fh,enc_hidden_sh, enc_hidden_fc,enc_hidden_sc = encoder(inputs, hidden)

    dec_hidden_fh = enc_hidden_fh
    dec_hidden_sh = enc_hidden_sh
    dec_hidden_fc = enc_hidden_fc
    dec_hidden_sc = enc_hidden_sc
    #dec_input = tf.expand_dims([targ_lang.word_index['<start> ']], 0)
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

    for t in range(max_length_targ):
        predictions, dec_hidden_fh,dec_hidden_fc,dec_hidden_sh,dec_hidden_sc, attention_weights = decoder(dec_input,
                                                         dec_hidden_fh,dec_hidden_fc,dec_hidden_sh,dec_hidden_sc,
                                                         enc_out)

        # storing the attention weights to plot later on
        attention_weights = tf.reshape(attention_weights, (-1, ))
        attention_plot[t] = attention_weights.numpy()

        predicted_id = tf.argmax(predictions[0]).numpy()

        result += targ_lang.index_word[predicted_id] + ' '

        #if targ_lang.index_word[predicted_id] == ' <end>':
        if targ_lang.index_word[predicted_id] == '<end>':
            return result, sentence

        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence

# %%
def translate(sentence):
    result, sentence = evaluate(sentence)

    print('Input: %s' % (sentence))
    print('Predicted translation: {}'.format(result))

    # attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
    # plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
# import tensorflow as tf
# checkpoint.restore(tf.train.latest_checkpoint('/content/drive/My Drive/seq2seq_3조/bilstm_adam_model/training_checkpoints'))

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('어린 아이들이 스포츠를 즐기기엔 많이 힘들죠')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-771b40bcf735> in <module>()
# ----> 1 translate('어린 아이들이 스포츠를 즐기기엔 많이 힘들죠')
#
# <ipython-input-36-c2a2e768d4a2> in translate(sentence)
#       1 def translate(sentence):
# ----> 2     result, sentence = evaluate(sentence)
#       3
#       4     print('Input: %s' % (sentence))
#       5     print('Predicted translation: {}'.format(result))
#
# <ipython-input-35-067c49daa3a6> in evaluate(sentence)
#       4     sentence = preprocess_sentence(sentence)
#       5
# ----> 6     inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
#       7     inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
#       8                                                          maxlen=max_length_inp,
#
# <ipython-input-35-067c49daa3a6> in <listcomp>(.0)
#       4     sentence = preprocess_sentence(sentence)
#       5
# ----> 6     inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
#       7     inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
#       8                                                          maxlen=max_length_inp,
#
# KeyError: '즐기기엔'

# %%
translate('아빠는 밥 먹었어?')
# Out:
# Input: <start> 아빠는 밥 먹었어 ? <end>
# Predicted translation: coffee go to see a lunch ? <end>

# %%
translate('하루에 한번 연락하는 게 그렇게 힘들어?')
# Out:
# Input: <start> 하루에 한번 연락하는 게 그렇게 힘들어 ? <end>
# Predicted translation: how is so tired on while ? <end>

# %%
def translate_4_bleu(sentence):
    result, sentence = evaluate(sentence)
    return result

# %%
# 테스트셋 가져오기
en_list = list(df['en'].loc[63000:])
en_list[-5:]
ko_list =list(df['ko'].loc[63000:])
ko_list[-5:]
# Out:
# ['나의 고민은 학교가 멀어서 통학하기 힘들어.',
#  '난 지금 내고양이때문에 충분히 힘들어.',
#  '나와 대화가 어려운 것이 많이 힘들어?',
#  '하루에 한번 연락하는게 그렇게 힘들어?',
#  '어린 아이들이 스포츠를 즐기기엔 많이 힘들죠.']

# %%
ko_list[6]
# Out:
# '그리고 주문한 상품중 탑세개가 사이즈가 작아요.'

# %%
translate_4_bleu(ko_list[3]).split()[:-1]
# Out:
# ['the', 'vacation', 'starts', 'next', 'week', '.']

# %%
# bleu
import nltk.translate.bleu_score as bleu
from nltk.translate.bleu_score import SmoothingFunction
def sentences_to_bleu(ref, pred):
  """
  ref : 참고용 타겟 문장(학습용 영어 문장)
  pred : 예측 문장(번역 결과)
  """
  smoothie = SmoothingFunction().method4
  return bleu.sentence_bleu(ref, pred, smoothing_function=smoothie)

# %%
from tqdm import tqdm_notebook
reference = []
pred = []
bleu_score = []
err_cnt = 0
smoothie = SmoothingFunction().method4
for i in tqdm_notebook(range(12000)):
  try: 
    decoded_sentence = translate_4_bleu(ko_list[i]).split()[:-1]
    reference= en_list[i].split()
    pred = decoded_sentence
    #bleu_score.append(bleu.sentence_bleu(list(map(lambda ref: ref.split(), reference)),decoded_sentence.split()))
    bleu_score.append(sentences_to_bleu(reference,pred))

  except KeyError:
    err_cnt += 1
    pass
print(err_cnt)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
# HBox(children=(FloatProgress(value=0.0, max=12000.0), HTML(value='')))
# 10035

# %%
print(reference)
print(pred)
# Out:
# ['Is', 'having', 'difficulties', 'in', 'talking', 'with', 'me', 'too', 'hard', 'for', 'you?']
# ['easy', 'working', 'easy', '?']

# %%
np.array(bleu_score).mean()
# Out:
# 0.21738665585704872
